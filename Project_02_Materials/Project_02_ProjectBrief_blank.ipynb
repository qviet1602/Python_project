# %% [markdown]
# # Project 2: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 2 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Importing Data from JSON files

# %% [markdown]
# 1. __Import__ the json files __blockbusters.json__, __blockbusters2.json__, __blockbusters3.json__ and load the datasets into Pandas DataFrames.

# %%
import pandas as pd
import json
pd.options.display.max_columns = 30

# %%
with open("blockbusters.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 136},
#  {'title': 'Avengers: Infinity War',
#   'id': 299536,
#   'revenue': 2046239637,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 149},
#  {'title': 'Titanic',
#   'id': 597,
#   'revenue': 1845034188,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': None,
#   'runtime': 194},
#  {'title': 'Jurassic World',
#   'id': 135397,
#   'revenue': 1671713208,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 124},
#  {'title': 'The Lion King',
#   'id': 420818,
#   'revenue': 1656943394,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': None,
#   'runtime': 118},
#  {'title': 'The Avengers',
#   'id': 24428,
#   'revenue': 1519557910,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 143},
#  {'title': 'Furious 7',
#   'id': 168259,
#   'revenue': 1506249360,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/uv63yAGg1zETAs1XQsOQpava87l.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'runtime': 137},
#  {'title': 'Avengers: Age of Ultron',
#   'id': 99861,
#   'revenue': 1405403694,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 141},
#  {'title': 'Black Panther',
#   'id': 284054,
#   'revenue': 1346739107,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg',
#    'backdrop_path': '/1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg'},
#   'runtime': 134},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'id': 12445,
#   'revenue': 1341511219,
#   'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'},
#   'runtime': 130},
#  {'title': 'Star Wars: The Last Jedi',
#   'id': 181808,
#   'revenue': 1332539889,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 152},
#  {'title': 'Frozen II',
#   'id': 330457,
#   'revenue': 1330764959,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 104},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'id': 351286,
#   'revenue': 1303459585,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 129},
#  {'title': 'Frozen',
#   'id': 109445,
#   'revenue': 1274219009,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 102},
#  {'title': 'Beauty and the Beast',
#   'id': 321612,
#   'revenue': 1263521126,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'belongs_to_collection': None,
#   'runtime': 129},
#  {'title': 'Incredibles 2',
#   'id': 260513,
#   'revenue': 1241891456,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/l7GqbzkJwowYRIXAtUz2iCPi64a.jpg',
#    'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'},
#   'runtime': 118}]

# %%
df2 = pd.read_json('blockbusters2.json', orient = 'column')
df2.head()
# Out:
#                           title      id     revenue  \
# 0             Avengers: Endgame  299534  2797800564
# 1                        Avatar   19995  2787965087
# 2  Star Wars: The Force Awakens  140607  2068223624
# 3        Avengers: Infinity War  299536  2046239637
# 4                       Titanic     597  1845034188
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                belongs_to_collection  runtime
# 0  {'id': 86311, 'name': 'The Avengers Collection...      181
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3  {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                               None      194

# %%
df3 = pd.read_json('blockbusters3.json', orient = 'split')
df3.head()
# Out:
#                           title      id     revenue  \
# 0             Avengers: Endgame  299534  2797800564
# 1                        Avatar   19995  2787965087
# 2  Star Wars: The Force Awakens  140607  2068223624
# 3        Avengers: Infinity War  299536  2046239637
# 4                       Titanic     597  1845034188
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                belongs_to_collection  runtime
# 0  {'id': 86311, 'name': 'The Avengers Collection...      181
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3  {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                               None      194

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %% [markdown]
# 2. __Create an account__ on https://www.themoviedb.org/

# %% [markdown]
# 3. Get your personal __API Key__

# %% [markdown]
# 4. __API-Request__ (movie module): Load all available information for the movie with __movie id = 140607__ into a Pandas DataFrame. <br> See https://developers.themoviedb.org/3/movies/get-movie-details for more information

# %%
import config
import requests
api_key  = 'api_key=' + config.api_key
api_key
# Out:
# 'api_key=f87c31e443414f56263b3306d1fada82'

# %%
movie_id = 140607

# %%
movie_api = "https://api.themoviedb.org/3/movie/{}?"
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=f87c31e443414f56263b3306d1fada82'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data = r.json()
type(data)
# Out:
# dict

# %%
data_df = pd.Series(data)
data_df = data_df.to_frame().T
data_df
# Out:
#    adult                     backdrop_path  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview popularity  \
# 0  Thirty years after defeating the Galactic Empi...     46.289
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#   runtime                                   spoken_languages    status  \
# 0     136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#   vote_average vote_count
# 0          7.4      15717

# %%
pd.json_normalize(data, sep = "_")
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg  245000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview  popularity  \
# 0  Thirty years after defeating the Galactic Empi...      46.289
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#    runtime                                   spoken_languages    status  \
# 0      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#    vote_average  vote_count  belongs_to_collection_id  \
# 0           7.4       15717                        10
#
#   belongs_to_collection_name belongs_to_collection_poster_path  \
# 0       Star Wars Collection  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg
#
#   belongs_to_collection_backdrop_path
# 0    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg

# %%
pd.json_normalize(data, record_path = 'genres', meta = 'id', meta_prefix = 'movies_')
# Out:
#     id             name movies_id
# 0   28           Action    140607
# 1   12        Adventure    140607
# 2  878  Science Fiction    140607
# 3   14          Fantasy    140607

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %% [markdown]
# 5. __API-Request__ (discover module): Load all movies with __release date between 2020-01-01 and 2020-02-29__ into a Pandas DataFrame. <br>
# See https://www.themoviedb.org/documentation/api/discover and https://developers.themoviedb.org/3/discover/movie-discover for more information.

# %%
date_api = 'https://api.themoviedb.org/3/discover/movie?{}&primary_release_date.gte={}&primary_release_date.lte={}'
date1 = '2020-01-01'
date2 = '2020-02-29'
url2 = date_api.format(api_key, date1,date2)
url2
# Out:
# 'https://api.themoviedb.org/3/discover/movie?api_key=f87c31e443414f56263b3306d1fada82&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29'

# %%
r2 =requests.get(url2)

# %%
data2 = r2.json()
type(data2)
# Out:
# dict

# %%
data2_df = pd.DataFrame(data2['results'])
data2_df.head()
# Out:
#    adult                     backdrop_path                    genre_ids  \
# 0  False  /jiqD14fg7UTZOT6qgvzTmfRYpWI.jpg                     [28, 80]
# 1  False  /3N316jUSdhvPyYTW29G4v9ebbcS.jpg                 [53, 28, 80]
# 2  False  /1umKVgbjFG5Cho5ZKTpcvRFJjuJ.jpg                 [35, 53, 80]
# 3  False  /6mKAKhj8POVGqV1GsroS5mGIUe9.jpg                 [14, 28, 12]
# 4  False  /5VKquU8PNujrxLmsYGHf2TCRNFQ.jpg  [878, 28, 12, 9648, 36, 14]
#
#        id original_language  \
# 0  495764                en
# 1   38700                en
# 2  609242                es
# 3  666750                en
# 4  582306                en
#
#                                       original_title  \
# 0  Birds of Prey (and the Fantabulous Emancipatio...
# 1                                  Bad Boys for Life
# 2                                  El robo del siglo
# 3                             Dragonheart: Vengeance
# 4                                   Assassin 33 A.D.
#
#                                             overview  popularity  \
# 0  Harley Quinn joins forces with a singer, an as...     405.833
# 1  Marcus and Mike are forced to confront new thr...     388.348
# 2  In 2006, a group of thieves performed what is ...     325.219
# 3  Lukas, a young farmer whose family is killed b...     304.248
# 4  When a billionaire gives a group of young scie...     305.144
#
#                         poster_path release_date  \
# 0  /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg   2020-02-05
# 1  /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   2020-01-15
# 2  /aSGwXbaTMxUhrfXT6xyZKqoklfB.jpg   2020-01-16
# 3  /qs6gz6atyQcAvqC6qZaslOjliUG.jpg   2020-02-04
# 4  /8jDvtdH327I8TgX3UPdkAsZF1dA.jpg   2020-01-24
#
#                                                title  video  vote_average  \
# 0  Birds of Prey (and the Fantabulous Emancipatio...  False           7.1
# 1                                  Bad Boys for Life  False           7.2
# 2                           The Heist of the Century  False           7.9
# 3                             Dragonheart: Vengeance  False           7.0
# 4                                   Assassin 33 A.D.  False           5.2
#
#    vote_count
# 0        7415
# 1        6225
# 2         484
# 3         218
# 4          58

# %%
data2_df.sort_values(by = 'release_date', ascending = False).head()
# Out:
#     adult                     backdrop_path     genre_ids      id  \
# 8   False  /4br4B8C0SRIYcKHUgoaOlGo50MU.jpg          [27]  575088
# 18  False  /fssCO59bqU5f0zngeYKex0g1vyb.jpg      [35, 28]  457335
# 10  False  /a8ppJJIQmEJcLSFfhxupc4aT4KW.jpg  [18, 28, 53]  571785
# 11  False  /p6ExERRwodksg0fFKzCjmNCR6Hw.jpg          [53]  531299
# 12  False  /cGUxPXVZF5n5P09dnlhWC8bLVp7.jpg      [18, 53]  505225
#
#    original_language            original_title  \
# 8                 ru  Яга. Кошмар тёмного леса
# 18                en               Guns Akimbo
# 10                ko                    사냥의 시간
# 11                en                Kill Chain
# 12                en  The Last Thing He Wanted
#
#                                              overview  popularity  \
# 8   The young family who moved to a new apartment ...     181.197
# 18  An ordinary guy suddenly finds himself forced ...      94.737
# 10  Four young men who want to leave their dystopi...     184.058
# 11  A hotel room shootout between two assassins ki...     173.868
# 12  At the turning point of the Iran-Contra affair...     173.162
#
#                          poster_path release_date  \
# 8   /8m5HTXzwewlfXhtZtLlLts53YTW.jpg   2020-02-27
# 18  /vV23MzddmlZJ6TIXpmRUyGV9961.jpg   2020-02-27
# 10  /bkuuvDoPkOJpg0ZDzHkUWt8ZG5A.jpg   2020-02-22
# 11  /wy0Xs5mGtD92PyKvsl0lxzbzscG.jpg   2020-02-20
# 12   /gItrnbEbMBbUrdIkFz8kgS2gkt.jpg   2020-02-14
#
#                                    title  video  vote_average  vote_count
# 8   Baba Yaga: Terror of the Dark Forest  False           6.1         124
# 18                           Guns Akimbo  False           6.5        1323
# 10                          Time to Hunt  False           7.3         177
# 11                            Kill Chain  False           5.5          71
# 12              The Last Thing He Wanted  False           5.0         326

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %% [markdown]
# 6. __API-Request__ (movie module): Load all available information for the movies with movie id = [__299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513__] into a Pandas DataFrame and __save the dataset in a local json file__.

# %%
movie_id = [19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
movie_api
url
# Out:
# 'https://api.themoviedb.org/3/movie/260513?api_key=f87c31e443414f56263b3306d1fada82'

# %%
movie_id1 = '299534'
url = movie_api.format(movie_id1) + api_key
r = requests.get(url)
data = r.json()
data_df = pd.Series(data)
data_df = data_df.to_frame().T
data_df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  356000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
#
#                                          homepage      id    imdb_id  \
# 0  https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
#
#   original_language     original_title  \
# 0                en  Avengers: Endgame
#
#                                             overview popularity  \
# 0  After the devastating events of Avengers: Infi...    250.137
#
#                         poster_path  \
# 0  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg
#
#                                 production_companies  \
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24  2797800564
#
#   runtime                                   spoken_languages    status  \
# 0     181  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                            tagline              title  video vote_average  \
# 0  Part of the journey is the end.  Avengers: Endgame  False          8.3
#
#   vote_count
# 0      18001

# %%
for i in movie_id:
    url = movie_api.format(i) + api_key
    r = requests.get(url)
    data = r.json()
    data = pd.Series(data)
    data = data.to_frame().T
    data_df = pd.concat([data_df, data], axis =0, ignore_index=True)

# %%
data_df.head(n=3)
# Out:
#    adult                     backdrop_path  \
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1  False  /AmHOQ7rpHwiaUMRjKXztnauSJb7.jpg
# 2  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  356000000
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1                        http://www.avatarmovie.com/   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en             Avengers: Endgame
# 1                en                        Avatar
# 2                en  Star Wars: The Force Awakens
#
#                                             overview popularity  \
# 0  After the devastating events of Avengers: Infi...    250.137
# 1  In the 22nd century, a paraplegic Marine is di...     79.151
# 2  Thirty years after defeating the Galactic Empi...     53.303
#
#                         poster_path  \
# 0  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg
# 1  /6EiRUJpuoeQPghrs3YNktfnqOVh.jpg
# 2  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 1  [{'id': 444, 'logo_path': '/42UPdZl6B2cFXgNUAS...
# 2  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24  2797800564
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-10  2787965087
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#   runtime                                   spoken_languages    status  \
# 0     181  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1     162  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                            tagline                         title  video  \
# 0  Part of the journey is the end.             Avengers: Endgame  False
# 1      Enter the World of Pandora.                        Avatar  False
# 2    Every generation has a story.  Star Wars: The Force Awakens  False
#
#   vote_average vote_count
# 0          8.3      18001
# 1          7.5      23289
# 2          7.4      15740

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %% [markdown]
# # ++++++++++++++ Hints +++++++++++++++++++++

# %% [markdown]
# __Hints for 1.__ <br>
# To load json files you can use

# %%
with open("filename.json") as f:
    data = json.load(f)

# %% [markdown]
# and

# %%
pd.DataFrame(data), pd.read_json(filename.json), pd.json_normalize(data)

# %% [markdown]
# the json files have the following orientation (important when using pd.read_json()):
# - blockbusters.json -> record
# - blockbusters2.json -> column
# - blockbusters3.json -> split

# %% [markdown]
# __Hints for 4., 5., 6.__<br>
# Make API GET-requests with the library requests (import requests):

# %%
data = requests.get(url).json()

# %% [markdown]
# __Hints for 4. and 6.,__ <br> url structure for movie module:

# %% [markdown]
# "https://api.themoviedb.org/3/movie/insert_movie_id?api_key=insert_api_key" (replace "insert_movie_id" with movie id and "insert_api_key" with your personal api-key)

# %% [markdown]
# __Hints for 5.__<br>
# url structure for discover module:

# %% [markdown]
# "https://api.themoviedb.org/3/discover/movie?api_key=insert_api_key&query1&query2..." (replace "insert_api_key" with your personal api-key and add appropriate queries)
