# %% [markdown]
# # Project 3: Data Cleaning - Tidy up messy Datasets (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 3 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## First Steps

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. __Load__ and __inspect__ the messy dataset __movies_metadata.csv__. Identify columns with nested / stringified json data.

# %%
movies = pd.read_csv('movies_metadata.csv')#, index_col = 'id')
movies.head(n =2)
# Out:
# /Users/jason1602/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3186: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %% [markdown]
# ## Dropping irrelevant Columns

# %% [markdown]
# 2. __Drop__ the irrelevant columns 'adult', 'imdb_id', 'original_title', 'video' and 'homepage'.

# %%
movies.drop(labels =['adult','original_title','imdb_id','video', 'homepage'], axis = 1, inplace = True)
movies.head(n=2)
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
#
#                                               genres    id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
#
#                         poster_path  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                    tagline      title  \
# 0  Released                                        NaN  Toy Story
# 1  Released  Roll the dice and unleash the excitement!    Jumanji
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0

# %% [markdown]
# ## How to handle stringified JSON columns

# %% [markdown]
# 3. __Evaluate__ Python Expressions in the stringified columns ["belongs_to_collection", "genres", "production_countries", "production_companies", "spoken_languages"] and __remove quotes__ ("") where possible.

# %%
import ast

# %%
movies['belongs_to_collection'] = movies.belongs_to_collection.map(ast.literal_eval,na_action ='ignore' )

# %%
movies.genres =movies.genres.map(ast.literal_eval, na_action = 'ignore')

# %%
movies.production_countries = movies.production_countries.map(ast.literal_eval, na_action = 'ignore')

# %%
movies.spoken_languages = movies.spoken_languages.map(ast.literal_eval, na_action = 'ignore')

# %% [markdown]
# ## How to flatten nested Columns

# %% [markdown]
# 4. __Extract__ only the __collection name__ from the column "belongs_to_collection" and __overwrite__ "belongs_to_collection". <br> For example: The value in the first row (Toy Story) should be 'Toy Story Collection'.

# %% [markdown]
# ### first way (better)

# %%
movies['belongs_to_collection'] = movies['belongs_to_collection'].apply(lambda x: x['name'] if isinstance(x, dict) else np.nan)

# %% [markdown]
# ### second way

# %%
# remove weird id
#movies = movies[~movies['id'].str.contains('-')]

# %%
#movies['belongs_to_collection']=movies.belongs_to_collection.map(lambda x: x['name'], na_action = 'ignore')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ly/_4dt2z5n1719v21bzqdjd1zr0000gr/T/ipykernel_7449/3253386183.py in <module>
# ----> 1 movies['belongs_to_collection']=movies.belongs_to_collection.map(lambda x: x['name'], na_action = 'ignore')
#
# ~/.local/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~/.local/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# ~/.local/lib/python3.7/site-packages/pandas/core/base.py in map_f(values, f)
#    1137
#    1138                 def map_f(values, f):
# -> 1139                     return lib.map_infer_mask(values, f, isna(values).view(np.uint8))
#    1140
#    1141             else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# /var/folders/ly/_4dt2z5n1719v21bzqdjd1zr0000gr/T/ipykernel_7449/3253386183.py in <lambda>(x)
# ----> 1 movies['belongs_to_collection']=movies.belongs_to_collection.map(lambda x: x['name'], na_action = 'ignore')
#
# TypeError: 'float' object is not subscriptable

# %%
#movies.head(n=2)
# Out:
#      belongs_to_collection    budget  \
# id
# 862   Toy Story Collection  30000000
# 8844                   NaN  65000000
#
#                                                  genres  \
# id
# 862   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 8844  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                   homepage    imdb_id original_language  \
# id
# 862   http://toystory.disney.com/toy-story  tt0114709                en
# 8844                                   NaN  tt0113497                en
#
#                                                overview popularity  \
# id
# 862   Led by Woody, Andy's toys live happily in his ...    21.9469
# 8844  When siblings Judy and Peter discover an encha...    17.0155
#
#                            poster_path  \
# id
# 862   /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 8844  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                    production_companies  ... release_date  \
# id                                                       ...
# 862      [{'name': 'Pixar Animation Studios', 'id': 3}]  ...   1995-10-30
# 8844  [{'name': 'TriStar Pictures', 'id': 559}, {'na...  ...   1995-12-15
#
#           revenue  runtime                                   spoken_languages  \
# id
# 862   373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 8844  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#         status                                    tagline      title  video  \
# id
# 862   Released                                        NaN  Toy Story  False
# 8844  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#      vote_average  vote_count
# id
# 862           7.7      5415.0
# 8844          6.9      2413.0
#
# [2 rows x 21 columns]

# %% [markdown]
# 5. __Extract__ all __genre names__ from the column "genres" and __overwrite__ "genres". If a movie has more than one genre, __seperate genres by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Animation|Comedy|Family'.

# %% [markdown]
# ### first way (better)

# %%
movies.genres[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
movies['genres'] = movies.genres.apply(lambda x: "|".join(i['name'] for i in x))

# %% [markdown]
# ### second way

# %%
def flatten(df, col):
    genres_ser = []
    for genres_dict in df[col]:
        genres_list = []
        if type(genres_dict) == float:
            pass
        else:
            for genre in genres_dict:
                genres_list.append(genre['name'])
        genres_list = '|'.join(genres_list)
        genres_ser.append(genres_list)
    return genres_ser

# %%
def test1(df, col):
    return df[col][0]

# %%
test1(movies, 'genres')
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
movies.genres
# Out:
# id
# 862       [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 8844      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 15602     [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 31357     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11862                        [{'id': 35, 'name': 'Comedy'}]
#                                 ...
# 439050    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 111109                        [{'id': 18, 'name': 'Drama'}]
# 67758     [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 227506                                                   []
# 461257                                                   []
# Name: genres, Length: 45463, dtype: object

# %%
movies['genres'] = flatten(movies, 'genres')
movies.genres
# Out:
# id
# 862        Animation|Comedy|Family
# 8844      Adventure|Fantasy|Family
# 15602               Romance|Comedy
# 31357         Comedy|Drama|Romance
# 11862                       Comedy
#                     ...
# 439050                Drama|Family
# 111109                       Drama
# 67758        Action|Drama|Thriller
# 227506
# 461257
# Name: genres, Length: 45463, dtype: object

# %% [markdown]
# 6. __Extract__ all __spoken language names__ from the column "spoken_languages" and __overwrite__ "spoken_languages". If a movie has more than one spoken language, __seperate spoken languages by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'English'.

# %%
movies.spoken_languages
# Out:
# id
# 862                [{'iso_639_1': 'en', 'name': 'English'}]
# 8844      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 15602              [{'iso_639_1': 'en', 'name': 'English'}]
# 31357              [{'iso_639_1': 'en', 'name': 'English'}]
# 11862              [{'iso_639_1': 'en', 'name': 'English'}]
#                                 ...
# 439050               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 111109                    [{'iso_639_1': 'tl', 'name': ''}]
# 67758              [{'iso_639_1': 'en', 'name': 'English'}]
# 227506                                                   []
# 461257             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45463, dtype: object

# %%
movies['spoken_languages'] = flatten(movies, 'spoken_languages')

# %%
movies.spoken_languages
# Out:
# id
# 862                English
# 8844      English|Français
# 15602              English
# 31357              English
# 11862              English
#                 ...
# 439050               فارسی
# 111109
# 67758              English
# 227506
# 461257             English
# Name: spoken_languages, Length: 45463, dtype: object

# %% [markdown]
# 7. __Extract__ all __production countries names__ from the column "production_countries" and __overwrite__ "production_countries". If a movie has more than one production country, __seperate production countries by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'United States of America'.

# %%
movies['production_countries'] = flatten(movies,'production_countries')

# %%
movies.production_countries
# Out:
# id
# 862       United States of America
# 8844      United States of America
# 15602     United States of America
# 31357     United States of America
# 11862     United States of America
#                     ...
# 439050                        Iran
# 111109                 Philippines
# 67758     United States of America
# 227506                      Russia
# 461257              United Kingdom
# Name: production_countries, Length: 45463, dtype: object

# %% [markdown]
# 8. __Extract__ all __production companies names__ from the column "production_companies" and __overwrite__ "production_companies". If a movie has more than one production company, __seperate production companies by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Pixar Animation Studios'

# %%
movies.production_companies = movies.production_companies.map(ast.literal_eval, na_action = 'ignore')

# %%
movies['production_companies'] = flatten(movies,'production_companies')

# %% [markdown]
# 9. __Inspect__ all columns above with value_counts(). Do you see anything strange? __Take reasonable measures__!

# %%
movies['production_countries'].replace("", np.nan, inplace =True)
movies['production_companies'].replace("", np.nan, inplace =True)
movies['spoken_languages'].replace("", np.nan, inplace =True)
movies.budget.value_counts()
# Out:
# 0           36573
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 12902809        1
# 24500           1
# 123690          1
# 3684600         1
# 40600000        1
# Name: budget, Length: 1223, dtype: int64

# %%
np.where(movies.production_companies == "")
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ## Cleaning Numerical Columns

# %% [markdown]
# 10. __Convert__ the datatype in the columns __"budget"__, __"id"__ and __"popularity"__ __to numeric__. Set invalid values as NaN.

# %%
movies['budget'] = pd.to_numeric(movies.budget, errors = 'coerce')

# %%
movies['id']= pd.to_numeric(movies.index, errors = 'coerce')
movies.set_index(keys='id')
# Out:
#                  belongs_to_collection    budget                    genres  \
# id
# 862               Toy Story Collection  30000000   Animation|Comedy|Family
# 8844                               NaN  65000000  Adventure|Fantasy|Family
# 15602        Grumpy Old Men Collection         0            Romance|Comedy
# 31357                              NaN  16000000      Comedy|Drama|Romance
# 11862   Father of the Bride Collection         0                    Comedy
# ...                                ...       ...                       ...
# 439050                             NaN         0              Drama|Family
# 111109                             NaN         0                     Drama
# 67758                              NaN         0     Action|Drama|Thriller
# 227506                             NaN         0
# 461257                             NaN         0
#
#                                     homepage    imdb_id original_language  \
# id
# 862     http://toystory.disney.com/toy-story  tt0114709                en
# 8844                                     NaN  tt0113497                en
# 15602                                    NaN  tt0113228                en
# 31357                                    NaN  tt0114885                en
# 11862                                    NaN  tt0113041                en
# ...                                      ...        ...               ...
# 439050  http://www.imdb.com/title/tt6209470/  tt6209470                fa
# 111109                                   NaN  tt2028550                tl
# 67758                                    NaN  tt0303758                en
# 227506                                   NaN  tt0008536                en
# 461257                                   NaN  tt6980792                en
#
#                                                  overview popularity  \
# id
# 862     Led by Woody, Andy's toys live happily in his ...    21.9469
# 8844    When siblings Judy and Peter discover an encha...    17.0155
# 15602   A family wedding reignites the ancient feud be...    11.7129
# 31357   Cheated on, mistreated and stepped on, the wom...    3.85949
# 11862   Just when George Banks has recovered from his ...    8.38752
# ...                                                   ...        ...
# 439050        Rising and falling between a man and woman.   0.072051
# 111109  An artist struggles to finish his work while a...   0.178241
# 67758   When one of her hits goes wrong, a professiona...   0.903007
# 227506  In a small town live two brothers, one a minis...   0.003503
# 461257  50 years after decriminalisation of homosexual...   0.163015
#
#                              poster_path  \
# id
# 862     /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 8844    /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 15602   /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 31357   /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 11862   /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                  ...
# 439050  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 111109  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 67758   /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 227506  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 461257  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                      production_companies  ... release_date  \
# id                                                         ...
# 862                               Pixar Animation Studios  ...   1995-10-30
# 8844    TriStar Pictures|Teitler Film|Interscope Commu...  ...   1995-12-15
# 15602                         Warner Bros.|Lancaster Gate  ...   1995-12-22
# 31357              Twentieth Century Fox Film Corporation  ...   1995-12-22
# 11862           Sandollar Productions|Touchstone Pictures  ...   1995-02-10
# ...                                                   ...  ...          ...
# 439050                                                NaN  ...          NaN
# 111109                                        Sine Olivia  ...   2011-11-17
# 67758                             American World Pictures  ...   2003-08-01
# 227506                                          Yermoliev  ...   1917-10-21
# 461257                                                NaN  ...   2017-06-09
#
#             revenue  runtime  spoken_languages    status  \
# id
# 862     373554033.0     81.0           English  Released
# 8844    262797249.0    104.0  English|Français  Released
# 15602           0.0    101.0           English  Released
# 31357    81452156.0    127.0           English  Released
# 11862    76578911.0    106.0           English  Released
# ...             ...      ...               ...       ...
# 439050          0.0     90.0             فارسی  Released
# 111109          0.0    360.0               NaN  Released
# 67758           0.0     90.0           English  Released
# 227506          0.0     87.0               NaN  Released
# 461257          0.0     75.0           English  Released
#
#                                                   tagline  \
# id
# 862                                                   NaN
# 8844            Roll the dice and unleash the excitement!
# 15602   Still Yelling. Still Fighting. Still Ready for...
# 31357   Friends are the people who let you be yourself...
# 11862   Just When His World Is Back To Normal... He's ...
# ...                                                   ...
# 439050         Rising and falling between a man and woman
# 111109                                                NaN
# 67758                              A deadly game of wits.
# 227506                                                NaN
# 461257                                                NaN
#
#                               title  video vote_average  vote_count
# id
# 862                       Toy Story  False          7.7      5415.0
# 8844                        Jumanji  False          6.9      2413.0
# 15602              Grumpier Old Men  False          6.5        92.0
# 31357             Waiting to Exhale  False          6.1        34.0
# 11862   Father of the Bride Part II  False          5.7       173.0
# ...                             ...    ...          ...         ...
# 439050                       Subdue  False          4.0         1.0
# 111109          Century of Birthing  False          9.0         3.0
# 67758                      Betrayal  False          3.8         6.0
# 227506             Satan Triumphant  False          0.0         0.0
# 461257                     Queerama  False          0.0         0.0
#
# [45463 rows x 21 columns]

# %%
movies['popularity']= pd.to_numeric(movies.popularity, errors = 'coerce')

# %% [markdown]
# 11. __Analyze__ the columns __"budget"__ and __"revenue"__ and __"runtime"__. Analyze movies with a budget/revenue/runtime of 0. Do you think the value 0 is the most appropriate value? __Take reasonable measures__!

# %%
movies.budget.replace(0, np.nan, inplace = True)
movies.runtime.replace(0, np.nan, inplace = True)
movies.revenue.replace(0, np.nan, inplace = True)

# %% [markdown]
# 12. The columns "budget" and "revenue" shall show values in Million USD. __Convert and Overwrite__!

# %%
movies['budget'] = movies.budget.map(lambda x: x/1000000)
movies['revenue'] = movies.revenue.map(lambda x: x/1000000)

# %% [markdown]
# 13. __Analyze__ movies with a __vote_count of 0__. What´s the __vote_average__ for those movies? Do you think this value is the most appropriate value? __Take reasonable measures__!

# %%
sum(movies[movies.vote_count == 0].vote_average != 0)
# Out:
# 0

# %%
movies.vote_count.replace(0, np.nan, inplace = True)
movies.vote_average.replace(0, np.nan, inplace = True)

# %% [markdown]
# ## Cleaning DateTime Columns

# %% [markdown]
# 14. __Convert__ the datatype in the column __"release_date"__ __to datetime__. Set invalid values as NaN.

# %%
movies.release_date = pd.to_datetime(movies.release_date, errors = 'coerce')

# %%
movies.release_date.dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Cleaning Text / String Columns

# %% [markdown]
# 15. __Analyze__ the text columns "overview" and "tagline". Try to identify __missing data that is not represented by NaN__ (e.g. "No Data"). __Replace as NaN__ (np.nan)!

# %%
movies[movies.overview.str.contains("No Data", na = False)]
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget, genres, homepage, imdb_id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, id]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Removing Duplicates

# %% [markdown]
# 16. __Identify__ and __remove__ duplicates!

# %%
movies[movies.duplicated(subset = 'id',keep = False)].sort_index(ascending = True)
# Out:
#        belongs_to_collection     budget  \
# id
# 4912                     NaN  30.000000
# 4912                     NaN  30.000000
# 10991     Pokémon Collection  16.000000
# 10991     Pokémon Collection  16.000000
# 12600     Pokémon Collection        NaN
# 12600     Pokémon Collection        NaN
# 13209                    NaN   0.002500
# 13209                    NaN   0.002500
# 14788                    NaN   1.600000
# 14788                    NaN   1.600000
# 15028                    NaN  26.000000
# 15028                    NaN  26.000000
# 22649                    NaN   0.000004
# 22649                    NaN   0.000004
# 69234                    NaN  10.000000
# 69234                    NaN  10.000000
# 77221                    NaN  40.000000
# 77221                    NaN  40.000000
# 84198                    NaN        NaN
# 84198                    NaN        NaN
# 109962                   NaN        NaN
# 109962                   NaN        NaN
# 110428                   NaN   3.512454
# 110428                   NaN   3.512454
# 132641                   NaN        NaN
# 132641                   NaN        NaN
#
#                                                    genres  \
# id
# 4912                  Comedy|Crime|Drama|Romance|Thriller
# 4912                  Comedy|Crime|Drama|Romance|Thriller
# 10991           Adventure|Fantasy|Animation|Action|Family
# 10991           Adventure|Fantasy|Animation|Action|Family
# 12600   Adventure|Fantasy|Animation|Science Fiction|Fa...
# 12600   Adventure|Fantasy|Animation|Science Fiction|Fa...
# 13209                                Drama|Comedy|Foreign
# 13209                                Drama|Comedy|Foreign
# 14788                                 Drama|Crime|Mystery
# 14788                                 Drama|Crime|Mystery
# 15028           Adventure|Family|Science Fiction|Thriller
# 15028           Adventure|Family|Science Fiction|Thriller
# 22649                                   Drama|Romance|War
# 22649                                   Drama|Romance|War
# 69234                 Drama|Horror|Music|Romance|TV Movie
# 69234                 Drama|Horror|Music|Romance|TV Movie
# 77221                                     Adventure|Drama
# 77221                                     Adventure|Drama
# 84198                                         Documentary
# 84198                                         Documentary
# 109962                                              Drama
# 109962                                              Drama
# 110428                                              Drama
# 110428                                              Drama
# 132641                                              Drama
# 132641                                              Drama
#
#                                                  homepage    imdb_id  \
# id
# 4912                                                  NaN  tt0270288
# 4912                                                  NaN  tt0270288
# 10991                   http://movies.warnerbros.com/pk3/  tt0235679
# 10991                   http://movies.warnerbros.com/pk3/  tt0235679
# 12600   http://www.pokemon.com/us/movies/movie-pokemon...  tt0287635
# 12600   http://www.pokemon.com/us/movies/movie-pokemon...  tt0287635
# 13209                                                 NaN  tt0499537
# 13209                                                 NaN  tt0499537
# 14788                       http://www.bubblethefilm.com/  tt0454792
# 14788                       http://www.bubblethefilm.com/  tt0454792
# 15028                                                 NaN  tt0157472
# 15028                                                 NaN  tt0157472
# 22649                                                 NaN  tt0022879
# 22649                                                 NaN  tt0022879
# 69234                                                 NaN  tt0100361
# 69234                                                 NaN  tt0100361
# 77221                                                 NaN  tt1701210
# 77221                                                 NaN  tt1701210
# 84198                                                 NaN  tt1736049
# 84198                                                 NaN  tt1736049
# 109962                                                NaN  tt0082992
# 109962                                                NaN  tt0082992
# 110428                                                NaN  tt2018086
# 110428                                                NaN  tt2018086
# 132641                                                NaN  tt0046468
# 132641                                                NaN  tt0046468
#
#        original_language                                           overview  \
# id
# 4912                  en  Television made him famous, but his biggest hi...
# 4912                  en  Television made him famous, but his biggest hi...
# 10991                 ja  When Molly Hale's sadness of her father's disa...
# 10991                 ja  When Molly Hale's sadness of her father's disa...
# 12600                 ja  All your favorite Pokémon characters are back,...
# 12600                 ja  All your favorite Pokémon characters are back,...
# 13209                 fa  Since women are banned from soccer matches, Ir...
# 13209                 fa  Since women are banned from soccer matches, Ir...
# 14788                 en  Set against the backdrop of a decaying Midwest...
# 14788                 en  Set against the backdrop of a decaying Midwest...
# 15028                 en  Until now, Zak Gibbs' greatest challenge has b...
# 15028                 en  Until now, Zak Gibbs' greatest challenge has b...
# 22649                 en  British nurse Catherine Barkley (Helen Hayes) ...
# 22649                 en  British nurse Catherine Barkley (Helen Hayes) ...
# 69234                 en  Count de Chagnie has discovered Christine's si...
# 69234                 en  Count de Chagnie has discovered Christine's si...
# 77221                 en  On the Arabian Peninsula in the 1930s, two war...
# 77221                 en  On the Arabian Peninsula in the 1930s, two war...
# 84198                 en  Using personal stories, this powerful document...
# 84198                 en  Using personal stories, this powerful document...
# 109962                en  Two literary women compete for 20 years: one w...
# 109962                en  Two literary women compete for 20 years: one w...
# 110428                fr  Winter, 1915. Confined by her family to an asy...
# 110428                fr  Winter, 1915. Confined by her family to an asy...
# 132641                ja  Ten years into a marriage, the wife is disappo...
# 132641                ja  Ten years into a marriage, the wife is disappo...
#
#         popularity                       poster_path  \
# id
# 4912      7.645827  /o3Im9nPLAgtlw1j2LtpMebAotSe.jpg
# 4912     11.331072  /o3Im9nPLAgtlw1j2LtpMebAotSe.jpg
# 10991    10.264597  /5ILjS6XB5deiHop8SXPsYxXWVPE.jpg
# 10991     6.480376  /5ILjS6XB5deiHop8SXPsYxXWVPE.jpg
# 12600     6.080108  /bqL0PVHbQ8Jmw3Njcl38kW0CoeM.jpg
# 12600     7.072301  /bqL0PVHbQ8Jmw3Njcl38kW0CoeM.jpg
# 13209     1.529879  /nfkOkpudNNIjRrf0mTFVoiGzHyc.jpg
# 13209     1.528960  /nfkOkpudNNIjRrf0mTFVoiGzHyc.jpg
# 14788     3.185256  /w56oo9nREcF54sNXVYuE9QxZFjT.jpg
# 14788     3.008299  /w56oo9nREcF54sNXVYuE9QxZFjT.jpg
# 15028     5.373623  /xGhDPrBz9mJN8CsIjA23jQSd3sc.jpg
# 15028     4.920175  /xGhDPrBz9mJN8CsIjA23jQSd3sc.jpg
# 22649     1.914697  /k0MF0IIbJ2PfOIku2KyraXL72d8.jpg
# 22649     2.411191  /k0MF0IIbJ2PfOIku2KyraXL72d8.jpg
# 69234     0.441872  /ole8e9YQwvHoKVpWO0lgfLFFemc.jpg
# 69234     0.438490  /ole8e9YQwvHoKVpWO0lgfLFFemc.jpg
# 77221     6.475665  /iQd7zWhSeCe3cgdPcLIDXjGfdzL.jpg
# 77221     6.652197  /iQd7zWhSeCe3cgdPcLIDXjGfdzL.jpg
# 84198     1.673307  /jn8L1QdWWX5c0NUOLjzaSXtZrbt.jpg
# 84198     0.501046  /jn8L1QdWWX5c0NUOLjzaSXtZrbt.jpg
# 109962   10.396878  /tOflyY8eUFWubLKJH7fKg4KwpCl.jpg
# 109962   12.180836  /tOflyY8eUFWubLKJH7fKg4KwpCl.jpg
# 110428    0.110065  /sGMPDg6je1zKi0TiX9b4pP6yN02.jpg
# 110428    0.134014  /sGMPDg6je1zKi0TiX9b4pP6yN02.jpg
# 132641    0.619388  /z9WiHt5uQjs8L8tyBpRBKzlheF2.jpg
# 132641    0.096079  /z9WiHt5uQjs8L8tyBpRBKzlheF2.jpg
#
#                                      production_companies  ...    revenue  \
# id                                                         ...
# 4912           Miramax Films|Allied Filmmakers|Mad Chance  ...  33.013805
# 4912           Miramax Films|Allied Filmmakers|Mad Chance  ...  33.013805
# 10991   TV Tokyo|4 Kids Entertainment|Nintendo|Pikachu...  ...  68.411275
# 10991   TV Tokyo|4 Kids Entertainment|Nintendo|Pikachu...  ...  68.411275
# 12600                                                 NaN  ...  28.023563
# 12600                                                 NaN  ...  28.023563
# 13209                       Jafar Panahi Film Productions  ...        NaN
# 13209                       Jafar Panahi Film Productions  ...        NaN
# 14788                     Magnolia Pictures|Extension 765  ...        NaN
# 14788                     Magnolia Pictures|Extension 765  ...        NaN
# 15028   Paramount Pictures|Nickelodeon Movies|Valhalla...  ...  38.793283
# 15028   Paramount Pictures|Nickelodeon Movies|Valhalla...  ...  38.793283
# 22649                                  Paramount Pictures  ...   0.000025
# 22649                                  Paramount Pictures  ...   0.000025
# 69234   Beta Film|Reteitalia|TF1|Hexatel|Saban/Scheric...  ...        NaN
# 69234   Beta Film|Reteitalia|TF1|Hexatel|Saban/Scheric...  ...        NaN
# 77221   France 2 Cinéma|Quinta Communications|Carthago...  ...   5.446000
# 77221   France 2 Cinéma|Quinta Communications|Carthago...  ...   5.446000
# 84198                                                 NaN  ...        NaN
# 84198                                                 NaN  ...        NaN
# 109962                   Metro-Goldwyn-Mayer (MGM)|Jaquet  ...        NaN
# 109962                   Metro-Goldwyn-Mayer (MGM)|Jaquet  ...        NaN
# 110428  Canal+|Arte France Cinéma|3B Productions|C.R.R...  ...   0.115860
# 110428  Canal+|Arte France Cinéma|3B Productions|C.R.R...  ...   0.115860
# 132641                                       Toho Company  ...        NaN
# 132641                                       Toho Company  ...        NaN
#
#        runtime  spoken_languages    status  \
# id
# 4912     113.0           English  Released
# 4912     113.0           English  Released
# 10991     93.0           English  Released
# 10991     93.0           English  Released
# 12600     75.0               日本語  Released
# 12600     75.0               日本語  Released
# 13209     93.0             فارسی  Released
# 13209     93.0             فارسی  Released
# 14788     73.0           English  Released
# 14788     73.0           English  Released
# 15028     94.0     Český|English  Released
# 15028     94.0     Český|English  Released
# 22649     89.0           English  Released
# 22649     89.0           English  Released
# 69234    168.0  English|Italiano  Released
# 69234    168.0  English|Italiano  Released
# 77221    130.0           English  Released
# 77221    130.0           English  Released
# 84198     84.0           English  Released
# 84198     84.0           English  Released
# 109962   115.0           English  Released
# 109962   115.0           English  Released
# 110428    95.0          Français  Released
# 110428    95.0          Français  Released
# 132641    89.0               日本語  Released
# 132641    89.0               日本語  Released
#
#                                                   tagline  \
# id
# 4912              Some things are better left top secret.
# 4912              Some things are better left top secret.
# 10991                       Pokémon: Spell of the Unknown
# 10991                       Pokémon: Spell of the Unknown
# 12600                                                 NaN
# 12600                                                 NaN
# 13209                                                 NaN
# 13209                                                 NaN
# 14788                                                 NaN
# 14788                                                 NaN
# 15028   The adventure of a lifetime, in a few mere sec...
# 15028   The adventure of a lifetime, in a few mere sec...
# 22649           Every woman who has loved will understand
# 22649           Every woman who has loved will understand
# 69234                                                 NaN
# 69234                                                 NaN
# 77221                                                 NaN
# 77221                                                 NaN
# 84198                               One Nation. Underfed.
# 84198                               One Nation. Underfed.
# 109962  From the very beginning, they knew they'd be f...
# 109962  From the very beginning, they knew they'd be f...
# 110428                                                NaN
# 110428                                                NaN
# 132641                                                NaN
# 132641                                                NaN
#
#                                               title  video vote_average  \
# id
# 4912                Confessions of a Dangerous Mind  False          6.6
# 4912                Confessions of a Dangerous Mind  False          6.6
# 10991                 Pokémon: Spell of the Unknown  False          6.0
# 10991                 Pokémon: Spell of the Unknown  False          6.0
# 12600   Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 12600   Pokémon 4Ever: Celebi - Voice of the Forest  False          5.7
# 13209                                       Offside  False          6.7
# 13209                                       Offside  False          6.7
# 14788                                        Bubble  False          6.4
# 14788                                        Bubble  False          6.4
# 15028                                 Clockstoppers  False          4.9
# 15028                                 Clockstoppers  False          4.9
# 22649                            A Farewell to Arms  False          6.2
# 22649                            A Farewell to Arms  False          6.2
# 69234                      The Phantom of the Opera  False          5.0
# 69234                      The Phantom of the Opera  False          5.0
# 77221                                    Black Gold  False          5.9
# 77221                                    Black Gold  False          5.9
# 84198                          A Place at the Table  False          6.9
# 84198                          A Place at the Table  False          6.9
# 109962                              Rich and Famous  False          4.9
# 109962                              Rich and Famous  False          4.9
# 110428                         Camille Claudel 1915  False          7.0
# 110428                         Camille Claudel 1915  False          7.0
# 132641                                         Wife  False          NaN
# 132641                                         Wife  False          NaN
#
#        vote_count      id
# id
# 4912        281.0    4912
# 4912        281.0    4912
# 10991       143.0   10991
# 10991       144.0   10991
# 12600        82.0   12600
# 12600        82.0   12600
# 13209        27.0   13209
# 13209        27.0   13209
# 14788        36.0   14788
# 14788        36.0   14788
# 15028        89.0   15028
# 15028        90.0   15028
# 22649        29.0   22649
# 22649        29.0   22649
# 69234         3.0   69234
# 69234         3.0   69234
# 77221        77.0   77221
# 77221        77.0   77221
# 84198         7.0   84198
# 84198         7.0   84198
# 109962        7.0  109962
# 109962        7.0  109962
# 110428       20.0  110428
# 110428       20.0  110428
# 132641        NaN  132641
# 132641        NaN  132641
#
# [26 rows x 22 columns]

# %%
movies.drop_duplicates(subset = 'id', inplace = True)

# %%
print(len(pd.unique(movies.id)))
len(movies.id)
# Out:
# 45433
# 45433

# %%
unique_id = pd.DataFrame(pd.unique(movies.id), columns = ['id']).set_index(keys = 'id')

# %%
movies.index = pd.to_numeric(movies.index)

# %%
unique_movies = unique_id.merge(movies, how = 'left', left_index=True,right_index=True, indicator= True)

# %%
unique_movies['_merge']
# Out:
# id
# 2         both
# 3         both
# 5         both
# 6         both
# 11        both
#           ...
# 465044    both
# 467731    both
# 468343    both
# 468707    both
# 469172    both
# Name: _merge, Length: 45463, dtype: category
# Categories (3, object): [left_only, right_only, both]

# %% [markdown]
# ## Handling Missing Values & Removing Observations

# %% [markdown]
# 17. __Drop__ all rows/movies with unknown __id__ or __title__.

# %%
movies.drop('id', axis = 1, inplace = True)

# %%
movies[movies.index.isna()]
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget, genres, homepage, imdb_id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 21 columns]

# %%
movies = movies[movies.title.notna()]

# %%
movies.shape
# Out:
# (45430, 21)

# %% [markdown]
# 18. __Keep__ only those rows/movies in the df with __10 or more non-NaN__ values.

# %%
movies.loc[:,"not_na"] = np.sum(movies.notna(), axis = 1)

# %%
movies = movies[movies.not_na >= 10]

# %%
movies.shape
# Out:
# (45406, 22)

# %% [markdown]
# ## Final (Cleaning) Steps

# %% [markdown]
# 19. __Keep__ only those rows/movies in the df with __status "Released"__. Then __drop__ the column "status".

# %%
movies = movies[movies.status == "Released"]

# %%
movies.shape
# Out:
# (44966, 22)

# %% [markdown]
# 20. The Order of the columns should be as follows:

# %%
movies.rename(columns = {"budget":"budget_musd", "revenue":"revenue_musd"}, inplace = True)

# %%
list_columns = movies.columns.tolist()

# %%
list_columns
# Out:
# ['belongs_to_collection',
#  'budget_musd',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue_musd',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'not_na']

# %%
new_col_list = ["id", "title", "tagline", "release_date", "genres", "belongs_to_collection", 
"original_language", "budget_musd", "revenue_musd", "production_companies",
"production_countries", "vote_count", "vote_average", "popularity", "runtime",
"overview", "spoken_languages", "poster_path"]

# %%
list(set(list_columns)-set(new_col_list))
# Out:
# ['id']

# %%
movies.drop(labels = ['video', 'status', 'not_na', 'imdb_id', 'homepage'], axis =1, inplace = True)

# %%
movies.reset_index(inplace = True)
movies
# Out:
#            id           belongs_to_collection  budget_musd  \
# 0         862            Toy Story Collection         30.0
# 1        8844                             NaN         65.0
# 2       15602       Grumpy Old Men Collection          NaN
# 3       31357                             NaN         16.0
# 4       11862  Father of the Bride Collection          NaN
# ...       ...                             ...          ...
# 44961  439050                             NaN          NaN
# 44962  111109                             NaN          NaN
# 44963   67758                             NaN          NaN
# 44964  227506                             NaN          NaN
# 44965  461257                             NaN          NaN
#
#                          genres original_language  \
# 0       Animation|Comedy|Family                en
# 1      Adventure|Fantasy|Family                en
# 2                Romance|Comedy                en
# 3          Comedy|Drama|Romance                en
# 4                        Comedy                en
# ...                         ...               ...
# 44961              Drama|Family                fa
# 44962                     Drama                tl
# 44963     Action|Drama|Thriller                en
# 44964                                          en
# 44965                                          en
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 44961        Rising and falling between a man and woman.    0.072051
# 44962  An artist struggles to finish his work while a...    0.178241
# 44963  When one of her hits goes wrong, a professiona...    0.903007
# 44964  In a small town live two brothers, one a minis...    0.003503
# 44965  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 44961  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 44962  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 44963  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 44964  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 44965  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 44961                                                NaN
# 44962                                        Sine Olivia
# 44963                            American World Pictures
# 44964                                          Yermoliev
# 44965                                                NaN
#
#            production_countries release_date  revenue_musd  runtime  \
# 0      United States of America   1995-10-30    373.554033     81.0
# 1      United States of America   1995-12-15    262.797249    104.0
# 2      United States of America   1995-12-22           NaN    101.0
# 3      United States of America   1995-12-22     81.452156    127.0
# 4      United States of America   1995-02-10     76.578911    106.0
# ...                         ...          ...           ...      ...
# 44961                      Iran          NaT           NaN     90.0
# 44962               Philippines   2011-11-17           NaN    360.0
# 44963  United States of America   2003-08-01           NaN     90.0
# 44964                    Russia   1917-10-21           NaN     87.0
# 44965            United Kingdom   2017-06-09           NaN     75.0
#
#        spoken_languages                                            tagline  \
# 0               English                                                NaN
# 1      English|Français          Roll the dice and unleash the excitement!
# 2               English  Still Yelling. Still Fighting. Still Ready for...
# 3               English  Friends are the people who let you be yourself...
# 4               English  Just When His World Is Back To Normal... He's ...
# ...                 ...                                                ...
# 44961             فارسی         Rising and falling between a man and woman
# 44962               NaN                                                NaN
# 44963           English                             A deadly game of wits.
# 44964               NaN                                                NaN
# 44965           English                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 44961                       Subdue           4.0         1.0
# 44962          Century of Birthing           9.0         3.0
# 44963                     Betrayal           3.8         6.0
# 44964             Satan Triumphant           NaN         NaN
# 44965                     Queerama           NaN         NaN
#
# [44966 rows x 18 columns]

# %%
movies = movies[new_col_list]

# %%
movies
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44961  439050                       Subdue
# 44962  111109          Century of Birthing
# 44963   67758                     Betrayal
# 44964  227506             Satan Triumphant
# 44965  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44961         Rising and falling between a man and woman          NaT
# 44962                                                NaN   2011-11-17
# 44963                             A deadly game of wits.   2003-08-01
# 44964                                                NaN   1917-10-21
# 44965                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44961              Drama|Family                             NaN
# 44962                     Drama                             NaN
# 44963     Action|Drama|Thriller                             NaN
# 44964                                                       NaN
# 44965                                                       NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 44961                fa          NaN           NaN
# 44962                tl          NaN           NaN
# 44963                en          NaN           NaN
# 44964                en          NaN           NaN
# 44965                en          NaN           NaN
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 44961                                                NaN
# 44962                                        Sine Olivia
# 44963                            American World Pictures
# 44964                                          Yermoliev
# 44965                                                NaN
#
#            production_countries  vote_count  vote_average  popularity  \
# 0      United States of America      5415.0           7.7   21.946943
# 1      United States of America      2413.0           6.9   17.015539
# 2      United States of America        92.0           6.5   11.712900
# 3      United States of America        34.0           6.1    3.859495
# 4      United States of America       173.0           5.7    8.387519
# ...                         ...         ...           ...         ...
# 44961                      Iran         1.0           4.0    0.072051
# 44962               Philippines         3.0           9.0    0.178241
# 44963  United States of America         6.0           3.8    0.903007
# 44964                    Russia         NaN           NaN    0.003503
# 44965            United Kingdom         NaN           NaN    0.163015
#
#        runtime                                           overview  \
# 0         81.0  Led by Woody, Andy's toys live happily in his ...
# 1        104.0  When siblings Judy and Peter discover an encha...
# 2        101.0  A family wedding reignites the ancient feud be...
# 3        127.0  Cheated on, mistreated and stepped on, the wom...
# 4        106.0  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44961     90.0        Rising and falling between a man and woman.
# 44962    360.0  An artist struggles to finish his work while a...
# 44963     90.0  When one of her hits goes wrong, a professiona...
# 44964     87.0  In a small town live two brothers, one a minis...
# 44965     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                       poster_path
# 0               English  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      English|Français  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2               English  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3               English  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4               English  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                 ...                               ...
# 44961             فارسی  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 44962               NaN  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 44963           English  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 44964               NaN  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 44965           English  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
# [44966 rows x 18 columns]

# %% [markdown]
# 21. __Reset__ the Index and create a __RangeIndex__.

# %% [markdown]
# 22. __Save__ the cleaned dataset in a __csv-file__.

# %%
movies.to_csv("movies_clean_practice2.csv", index = False)

# %%
pd.read_csv("movies_clean_practice2.csv")
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44961  439050                       Subdue
# 44962  111109          Century of Birthing
# 44963   67758                     Betrayal
# 44964  227506             Satan Triumphant
# 44965  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44961         Rising and falling between a man and woman          NaN
# 44962                                                NaN   2011-11-17
# 44963                             A deadly game of wits.   2003-08-01
# 44964                                                NaN   1917-10-21
# 44965                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44961              Drama|Family                             NaN
# 44962                     Drama                             NaN
# 44963     Action|Drama|Thriller                             NaN
# 44964                       NaN                             NaN
# 44965                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 44961                fa          NaN           NaN
# 44962                tl          NaN           NaN
# 44963                en          NaN           NaN
# 44964                en          NaN           NaN
# 44965                en          NaN           NaN
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 44961                                                NaN
# 44962                                        Sine Olivia
# 44963                            American World Pictures
# 44964                                          Yermoliev
# 44965                                                NaN
#
#            production_countries  vote_count  vote_average  popularity  \
# 0      United States of America      5415.0           7.7   21.946943
# 1      United States of America      2413.0           6.9   17.015539
# 2      United States of America        92.0           6.5   11.712900
# 3      United States of America        34.0           6.1    3.859495
# 4      United States of America       173.0           5.7    8.387519
# ...                         ...         ...           ...         ...
# 44961                      Iran         1.0           4.0    0.072051
# 44962               Philippines         3.0           9.0    0.178241
# 44963  United States of America         6.0           3.8    0.903007
# 44964                    Russia         NaN           NaN    0.003503
# 44965            United Kingdom         NaN           NaN    0.163015
#
#        runtime                                           overview  \
# 0         81.0  Led by Woody, Andy's toys live happily in his ...
# 1        104.0  When siblings Judy and Peter discover an encha...
# 2        101.0  A family wedding reignites the ancient feud be...
# 3        127.0  Cheated on, mistreated and stepped on, the wom...
# 4        106.0  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44961     90.0        Rising and falling between a man and woman.
# 44962    360.0  An artist struggles to finish his work while a...
# 44963     90.0  When one of her hits goes wrong, a professiona...
# 44964     87.0  In a small town live two brothers, one a minis...
# 44965     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                       poster_path
# 0               English  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      English|Français  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2               English  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3               English  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4               English  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                 ...                               ...
# 44961             فارسی  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 44962               NaN  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 44963           English  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 44964               NaN  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 44965           English  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
# [44966 rows x 18 columns]

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %% [markdown]
# # ++++++++++++++++ Hints++++++++++++++++++++

# %% [markdown]
# __Hints for 3.__ <br>
# apply ast.literal_eval() on all stringified elements (you have to import ast):

# %%
# example:
df.stringified_column = df.stringified_column.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %% [markdown]
# __Hints for 4., 5., 6., 7., 8.__<br>
# apply an appropriate lambda function on all column elements

# %% [markdown]
# __Hints for 9.__<br>
# Replace all __""__ (empty strings) in the above columns by NaN (__np.nan__)

# %% [markdown]
# __Hints for 10.__<br>
# Use pd.to_numeric() and "coerce" errors

# %% [markdown]
# __Hints for 11.__<br>
# Replace the value 0 by NaN (__np.nan__)

# %% [markdown]
# __Hints for 13.__<br>
# Replace the value 0 by NaN (__np.nan__)

# %% [markdown]
# __Hints for 14.__<br>
# Use pd.to_datetime() and "coerce" errors

# %% [markdown]
# __Hints for 16.__<br>
# There cannot be two or more movies with the same movie id.
