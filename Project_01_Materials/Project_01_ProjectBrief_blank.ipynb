# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
movies = pd.read_csv('movies_complete.csv', index_col= 'id')
movies.head()
# Out:
#                              title  \
# id
# 862                      Toy Story
# 8844                       Jumanji
# 15602             Grumpier Old Men
# 31357            Waiting to Exhale
# 11862  Father of the Bride Part II
#
#                                                  tagline release_date  \
# id
# 862                                                  NaN   1995-10-30
# 8844           Roll the dice and unleash the excitement!   1995-12-15
# 15602  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 31357  Friends are the people who let you be yourself...   1995-12-22
# 11862  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                          genres           belongs_to_collection  \
# id
# 862     Animation|Comedy|Family            Toy Story Collection
# 8844   Adventure|Fantasy|Family                             NaN
# 15602            Romance|Comedy       Grumpy Old Men Collection
# 31357      Comedy|Drama|Romance                             NaN
# 11862                    Comedy  Father of the Bride Collection
#
#       original_language  budget_musd  revenue_musd  \
# id
# 862                  en         30.0    373.554033
# 8844                 en         65.0    262.797249
# 15602                en          NaN           NaN
# 31357                en         16.0     81.452156
# 11862                en          NaN     76.578911
#
#                                     production_companies  \
# id
# 862                              Pixar Animation Studios
# 8844   TriStar Pictures|Teitler Film|Interscope Commu...
# 15602                        Warner Bros.|Lancaster Gate
# 31357             Twentieth Century Fox Film Corporation
# 11862          Sandollar Productions|Touchstone Pictures
#
#            production_countries  ...  vote_average  popularity  runtime  \
# id                               ...
# 862    United States of America  ...           7.7   21.946943     81.0
# 8844   United States of America  ...           6.9   17.015539    104.0
# 15602  United States of America  ...           6.5   11.712900    101.0
# 31357  United States of America  ...           6.1    3.859495    127.0
# 11862  United States of America  ...           5.7    8.387519    106.0
#
#                                                 overview  spoken_languages  \
# id
# 862    Led by Woody, Andy's toys live happily in his ...           English
# 8844   When siblings Judy and Peter discover an encha...  English|Français
# 15602  A family wedding reignites the ancient feud be...           English
# 31357  Cheated on, mistreated and stepped on, the wom...           English
# 11862  Just when George Banks has recovered from his ...           English
#
#                                              poster_path  \
# id
# 862    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 8844   <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 15602  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 31357  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 11862  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                                                     cast cast_size  crew_size  \
# id
# 862    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13        106
# 8844   Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26         16
# 15602  Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7          4
# 31357  Whitney Houston|Angela Bassett|Loretta Devine|...        10         10
# 11862  Steve Martin|Diane Keaton|Martin Short|Kimberl...        12          7
#
#               director
# id
# 862      John Lasseter
# 8844      Joe Johnston
# 15602    Howard Deutch
# 31357  Forest Whitaker
# 11862    Charles Shyer
#
# [5 rows x 21 columns]

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
movies.sort_values(by='revenue_musd', ascending = False)[['title','revenue_musd']].head(5)
# Out:
#                                title  revenue_musd
# id
# 19995                         Avatar   2787.965087
# 140607  Star Wars: The Force Awakens   2068.223624
# 597                          Titanic   1845.034188
# 24428                   The Avengers   1519.557910
# 135397                Jurassic World   1513.528810

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
movies.nlargest(5,'budget_musd')[['title','budget_musd']]
# Out:
#                                              title  budget_musd
# id
# 1865   Pirates of the Caribbean: On Stranger Tides        380.0
# 285       Pirates of the Caribbean: At World's End        300.0
# 99861                      Avengers: Age of Ultron        280.0
# 1452                              Superman Returns        270.0
# 38757                                      Tangled        260.0

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
movies['profit_musd'] = movies['revenue_musd'] - movies['budget_musd']
movies.nlargest(5,'profit_musd')[['title','profit_musd']]
movies.head()
# Out:
#                              title  \
# id
# 862                      Toy Story
# 8844                       Jumanji
# 15602             Grumpier Old Men
# 31357            Waiting to Exhale
# 11862  Father of the Bride Part II
#
#                                                  tagline release_date  \
# id
# 862                                                  NaN   1995-10-30
# 8844           Roll the dice and unleash the excitement!   1995-12-15
# 15602  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 31357  Friends are the people who let you be yourself...   1995-12-22
# 11862  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                          genres           belongs_to_collection  \
# id
# 862     Animation|Comedy|Family            Toy Story Collection
# 8844   Adventure|Fantasy|Family                             NaN
# 15602            Romance|Comedy       Grumpy Old Men Collection
# 31357      Comedy|Drama|Romance                             NaN
# 11862                    Comedy  Father of the Bride Collection
#
#       original_language  budget_musd  revenue_musd  \
# id
# 862                  en         30.0    373.554033
# 8844                 en         65.0    262.797249
# 15602                en          NaN           NaN
# 31357                en         16.0     81.452156
# 11862                en          NaN     76.578911
#
#                                     production_companies  \
# id
# 862                              Pixar Animation Studios
# 8844   TriStar Pictures|Teitler Film|Interscope Commu...
# 15602                        Warner Bros.|Lancaster Gate
# 31357             Twentieth Century Fox Film Corporation
# 11862          Sandollar Productions|Touchstone Pictures
#
#            production_countries  ...  popularity  runtime  \
# id                               ...
# 862    United States of America  ...   21.946943     81.0
# 8844   United States of America  ...   17.015539    104.0
# 15602  United States of America  ...   11.712900    101.0
# 31357  United States of America  ...    3.859495    127.0
# 11862  United States of America  ...    8.387519    106.0
#
#                                                 overview  spoken_languages  \
# id
# 862    Led by Woody, Andy's toys live happily in his ...           English
# 8844   When siblings Judy and Peter discover an encha...  English|Français
# 15602  A family wedding reignites the ancient feud be...           English
# 31357  Cheated on, mistreated and stepped on, the wom...           English
# 11862  Just when George Banks has recovered from his ...           English
#
#                                              poster_path  \
# id
# 862    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 8844   <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 15602  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 31357  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 11862  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                                                     cast cast_size crew_size  \
# id
# 862    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13       106
# 8844   Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26        16
# 15602  Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7         4
# 31357  Whitney Houston|Angela Bassett|Loretta Devine|...        10        10
# 11862  Steve Martin|Diane Keaton|Martin Short|Kimberl...        12         7
#
#               director  profit_musd
# id
# 862      John Lasseter   343.554033
# 8844      Joe Johnston   197.797249
# 15602    Howard Deutch          NaN
# 31357  Forest Whitaker    65.452156
# 11862    Charles Shyer          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
movies['profit_musd'] = movies['revenue_musd'] - movies['budget_musd']
movies.nsmallest(5,'profit_musd')[['title','profit_musd']]
# Out:
#                                               title  profit_musd
# id
# 57201                               The Lone Ranger  -165.710090
# 10733                                     The Alamo  -119.180039
# 50321                               Mars Needs Moms  -111.007242
# 339964  Valerian and the City of a Thousand Planets  -107.447384
# 1911                               The 13th Warrior   -98.301101

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
movies10 = movies.copy()
movies10 = movies10[movies10['budget_musd']>=10]
movies10['ROI'] = movies10['revenue_musd']/movies10['budget_musd']
movies10.nlargest(5,'ROI')[['title','ROI']]
# Out:
#                             title        ROI
# id
# 601    E.T. the Extra-Terrestrial  75.520507
# 11                      Star Wars  70.490728
# 114                  Pretty Woman  33.071429
# 77338            The Intouchables  32.806221
# 1891      The Empire Strikes Back  29.911111

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
movies10.nsmallest(5,'ROI')[['title','ROI']]
# Out:
#                  title           ROI
# id
# 14844  Chasing Liberty  5.217391e-07
# 18475      The Cookout  7.500000e-07
# 33927         Deadfall  1.800000e-06
# 10944       In the Cut  1.916667e-06
# 98339    The Samaritan  2.100833e-04

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
movies.nlargest(5,'vote_count')[['title','vote_count']]
# Out:
#                   title  vote_count
# id
# 27205         Inception     14075.0
# 155     The Dark Knight     12269.0
# 19995            Avatar     12114.0
# 24428      The Avengers     12000.0
# 293660         Deadpool     11444.0

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
movies['vote_count'].apply(lambda cnt: int(cnt))
movies[movies['vote_count']>=10].nlargest(5,'vote_average')[['title','vote_average']]
# Out:
#                                                     title  vote_average
# id
# 130824  As I Was Moving Ahead Occasionally I Saw Brief...           9.5
# 420714                                    Planet Earth II           9.5
# 26397                                       The Civil War           9.2
# 19404                         Dilwale Dulhania Le Jayenge           9.1
# 409926                                             Cosmos           9.1

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
movies[movies['vote_count']>=10].nsmallest(5,'vote_average')[['title','vote_average']]
# Out:
#                                   title  vote_average
# id
# 279988   Extinction: Nature Has Evolved           0.0
# 398818             Call Me by Your Name           0.0
# 341689  How to Talk to Girls at Parties           0.0
# 22727          The Beast of Yucca Flats           1.6
# 13383                       Santa Claus           1.6

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
movies.nlargest(5,'popularity')[['title','popularity']]
# Out:
#                        title  popularity
# id
# 211672               Minions  547.488298
# 297762          Wonder Woman  294.337037
# 321612  Beauty and the Beast  287.253654
# 339403           Baby Driver  228.032744
# 177572            Big Hero 6  213.849907

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %%
movies.columns
# Out:
# Index(['title', 'tagline', 'release_date', 'genres', 'belongs_to_collection',
#        'original_language', 'budget_musd', 'revenue_musd',
#        'production_companies', 'production_countries', 'vote_count',
#        'vote_average', 'popularity', 'runtime', 'overview', 'spoken_languages',
#        'poster_path', 'cast', 'cast_size', 'crew_size', 'director',
#        'profit_musd'],
#       dtype='object')

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
#movies['genres'].apply(lambda genres: genres.split('|'))
#'Animation' in movies['genres'].iloc[0].split('|')
movies1 = movies.copy()
movies1 = movies1[movies1['genres'].notnull()]
# filter to only Science Fiction movies
movies1 = movies1[movies1['genres'].apply(lambda genres: 'Science Fiction' in genres.split('|'))]
# filter to only Bruce Willis movies
movies1 = movies1[movies1['cast'].notnull()]
movies1 = movies1[movies1['cast'].apply(lambda cast: 'Bruce Willis' in cast.split('|'))]
movies1.sort_values(by= 'vote_average', ascending = False)[['title', 'genres','cast','vote_average']]
# Out:
#                         title  \
# id
# 63             Twelve Monkeys
# 18          The Fifth Element
# 9741              Unbreakable
# 59967                  Looper
# 95                 Armageddon
# 5172     The Astronaut Farmer
# 19959              Surrogates
# 72559   G.I. Joe: Retaliation
# 31586                   North
# 307663                   Vice
#
#                                                    genres  \
# id
# 63                       Science Fiction|Thriller|Mystery
# 18      Adventure|Fantasy|Action|Thriller|Science Fiction
# 9741                       Science Fiction|Thriller|Drama
# 59967                     Action|Thriller|Science Fiction
# 95              Action|Thriller|Science Fiction|Adventure
# 5172               Adventure|Comedy|Drama|Science Fiction
# 19959                     Action|Science Fiction|Thriller
# 72559           Adventure|Action|Science Fiction|Thriller
# 31586         Comedy|Drama|Family|Fantasy|Science Fiction
# 307663          Thriller|Science Fiction|Action|Adventure
#
#                                                      cast  vote_average
# id
# 63      Bruce Willis|Madeleine Stowe|Brad Pitt|Christo...           7.4
# 18      Bruce Willis|Gary Oldman|Ian Holm|Milla Jovovi...           7.3
# 9741    Bruce Willis|Samuel L. Jackson|Robin Wright|Sp...           6.9
# 59967   Joseph Gordon-Levitt|Bruce Willis|Emily Blunt|...           6.6
# 95      Bruce Willis|Billy Bob Thornton|Ben Affleck|Li...           6.5
# 5172    Billy Bob Thornton|Virginia Madsen|Max Thierio...           6.2
# 19959   Bruce Willis|Radha Mitchell|Rosamund Pike|Jame...           5.9
# 72559   Dwayne Johnson|D.J. Cotrona|Adrianne Palicki|B...           5.4
# 31586   Elijah Wood|Jason Alexander|Julia Louis-Dreyfu...           4.8
# 307663  Ambyr Childers|Thomas Jane|Bryan Greenberg|Bru...           4.1

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
movies2 = movies.copy()
# remove null values
movies2.dropna(subset = ['cast', 'director'], how = 'any', inplace = True)
movies2 = movies2[movies2['cast'].apply(lambda cast: 'Uma Thurman' in cast.split('|'))]
movies2 = movies2[movies2['director'].apply(lambda director: 'Quentin Tarantino' in director.split('|'))]
movies2.sort_values(by='runtime')
# Out:
#                  title                                            tagline  \
# id
# 24   Kill Bill: Vol. 1                                   Go for the kill.
# 393  Kill Bill: Vol. 2               The bride is back for the final cut.
# 680       Pulp Fiction  Just because you are a character doesn't mean ...
#
#     release_date                 genres belongs_to_collection  \
# id
# 24    2003-10-10           Action|Crime  Kill Bill Collection
# 393   2004-04-16  Action|Crime|Thriller  Kill Bill Collection
# 680   1994-09-10         Thriller|Crime                   NaN
#
#     original_language  budget_musd  revenue_musd  \
# id
# 24                 en         30.0    180.949000
# 393                en         30.0    152.159461
# 680                en          8.0    213.928762
#
#                              production_companies      production_countries  \
# id
# 24   Miramax Films|A Band Apart|Super Cool ManChu  United States of America
# 393  Miramax Films|A Band Apart|Super Cool ManChu  United States of America
# 680       Miramax Films|A Band Apart|Jersey Films  United States of America
#
#      ...  popularity  runtime  \
# id   ...
# 24   ...   25.261865    111.0
# 393  ...   21.533072    136.0
# 680  ...  140.950236    154.0
#
#                                               overview  \
# id
# 24   An assassin is shot at the altar by her ruthle...
# 393  The Bride unwaveringly continues on her roarin...
# 680  A burger-loving hit man, his philosophical par...
#
#                   spoken_languages  \
# id
# 24            English|日本語|Français
# 393  English|普通话|Español|广州话 / 廣州話
# 680       English|Español|Français
#
#                                            poster_path  \
# id
# 24   <img src='http://image.tmdb.org/t/p/w185//v7Ta...
# 393  <img src='http://image.tmdb.org/t/p/w185//2yhg...
# 680  <img src='http://image.tmdb.org/t/p/w185//d5iI...
#
#                                                   cast cast_size crew_size  \
# id
# 24   Uma Thurman|Lucy Liu|Vivica A. Fox|Daryl Hanna...        36       161
# 393  Uma Thurman|David Carradine|Daryl Hannah|Micha...        27       130
# 680  John Travolta|Samuel L. Jackson|Uma Thurman|Br...        54        87
#
#               director  profit_musd
# id
# 24   Quentin Tarantino   150.949000
# 393  Quentin Tarantino   122.159461
# 680  Quentin Tarantino   205.928762
#
# [3 rows x 22 columns]

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
movies3 = movies.copy()
# remove null values
movies3.dropna(subset = ['production_companies','release_date'], how = 'any', inplace = True)
movies3 = movies3[movies3['production_companies'].apply(lambda x: 'Pixar Animation Studios' in x.split('|'))]
movies3['release_yr'] = movies3['release_date'].apply(lambda date: int(date.split('-')[0]))
movies3 = movies3[(movies3['release_yr'] >= 2010) & (movies3['release_yr'] <= 2015)]
movies3.sort_values(by = 'revenue_musd', ascending = False)[['title','production_companies','release_date','revenue_musd']]
# Out:
#                              title  \
# id
# 10193                  Toy Story 3
# 150540                  Inside Out
# 62211          Monsters University
# 49013                       Cars 2
# 62177                        Brave
# 105864           The Good Dinosaur
# 40619                  Day & Night
# 200481           The Blue Umbrella
# 213121        Toy Story of Terror!
# 83564                      La luna
# 77887            Hawaiian Vacation
# 82424                    Small Fry
# 130925             Partysaurus Rex
# 141423        The Legend of Mor'du
# 256835  Toy Story That Time Forgot
# 286192                        Lava
# 345637         Sanjay's Super Team
# 145316                   Air Mater
# 355338         Riley's First Date?
#
#                                 production_companies release_date  \
# id
# 10193   Walt Disney Pictures|Pixar Animation Studios   2010-06-16
# 150540  Walt Disney Pictures|Pixar Animation Studios   2015-06-09
# 62211   Walt Disney Pictures|Pixar Animation Studios   2013-06-20
# 49013   Walt Disney Pictures|Pixar Animation Studios   2011-06-11
# 62177   Walt Disney Pictures|Pixar Animation Studios   2012-06-21
# 105864  Walt Disney Pictures|Pixar Animation Studios   2015-11-14
# 40619   Walt Disney Pictures|Pixar Animation Studios   2010-06-17
# 200481                       Pixar Animation Studios   2013-02-12
# 213121  Walt Disney Pictures|Pixar Animation Studios   2013-10-15
# 83564                        Pixar Animation Studios   2011-01-01
# 77887                        Pixar Animation Studios   2011-06-16
# 82424                        Pixar Animation Studios   2011-11-23
# 130925  Walt Disney Pictures|Pixar Animation Studios   2012-09-14
# 141423                       Pixar Animation Studios   2012-01-01
# 256835                       Pixar Animation Studios   2014-12-02
# 286192                       Pixar Animation Studios   2015-06-21
# 345637                       Pixar Animation Studios   2015-11-25
# 145316                       Pixar Animation Studios   2011-08-04
# 355338  Walt Disney Pictures|Pixar Animation Studios   2015-11-03
#
#         revenue_musd
# id
# 10193    1066.969703
# 150540    857.611174
# 62211     743.559607
# 49013     559.852396
# 62177     538.983207
# 105864    331.926147
# 40619            NaN
# 200481           NaN
# 213121           NaN
# 83564            NaN
# 77887            NaN
# 82424            NaN
# 130925           NaN
# 141423           NaN
# 256835           NaN
# 286192           NaN
# 345637           NaN
# 145316           NaN
# 355338           NaN

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
movies4 = movies.copy()
# remove null values
movies4.dropna(subset = ['spoken_languages'], how = 'any', inplace = True)
movies4 = movies4[movies4['spoken_languages'].apply(lambda lang: 'English' in lang.split('|'))]
movies4[movies4['vote_average'] >= 7.5].sort_values(by = 'release_date', ascending = False)
# Out:
#                                                     title  \
# id
# 374471                                              Porto
# 460135              LEGO DC Super Hero Girls: Brain Drain
# 411741                                   Ingrid Goes West
# 374720                                            Dunkirk
# 416477                                       The Big Sick
# 461634      Rory Scovel Tries Stand-Up for the First Time
# 382614                                  The Book of Henry
# 433471                                                Lou
# 382127                                          Manifesto
# 461805                               The Putin Interviews
# 453008  Hell on Earth: The Fall of Syria and the Rise ...
# 305342                                               Dean
# 455661                                     In a Heartbeat
# 459295                   Sarah Silverman: A Speck of Dust
# 419192                                            McLaren
# 458310                      Hasan Minhaj: Homecoming King
# 458298                                        The Keepers
# 411007                       Abacus: Small Enough to Jail
# 387426                                               Okja
# 447818                                  Generation Iron 2
# 456348                                      Batman & Bill
# 454787                      Chris Gethard: Career Suicide
# 464207                          The Truth Is in the Stars
# 450875                                              LA 92
# 450945                                  I Am Heath Ledger
# 452166                                    The Reagan Show
# 355277                                      Born in China
# 283995                     Guardians of the Galaxy Vol. 2
# 411012                                      Chasing Trane
# 359784                                             Maudie
# ...                                                   ...
# 264309                                         Navy Blues
# 42616                                       The Virginian
# 94716                               A Cottage on Dartmoor
# 105981                                         Lucky Star
# 288521                                       Why Be Good?
# 28189                      The Fall of the House of Usher
# 31411                                       The Cameraman
# 42614                               Our Dancing Daughters
# 101482                                           Lonesome
# 28978                                          The Circus
# 73969                                        My Best Girl
# 27503                                         The Unknown
# 16661                                     The Kid Brother
# 961                                           The General
# 128899                           Bardelys the Magnificent
# 85638                                  The Scarlet Letter
# 73575                                            Sparrows
# 121379                              Lady Windermere's Fan
# 962                                         The Gold Rush
# 1405                                                Greed
# 992                                         Sherlock, Jr.
# 701                                       Our Hospitality
# 91208                                      Souls for Sale
# 23282                                            One Week
# 54242                                              Mickey
# 47653                                       The Immigrant
# 371758                           And Then There Were None
# 410142                                    Lo Sound Desert
# 426224                                   Jedi Junior High
# 425916                                      Salad Fingers
#
#                                                   tagline release_date  \
# id
# 374471                                                NaN   2017-09-14
# 460135                                                NaN   2017-08-30
# 411741                                 She'll follow you.   2017-08-11
# 374720                    The event that shaped our world   2017-07-19
# 416477                             An awkward true story.   2017-06-23
# 461634                                                NaN   2017-06-20
# 382614                         Never leave things undone.   2017-06-16
# 433471                                                NaN   2017-06-16
# 382127                            ALL CURRENT ART IS FAKE   2017-06-15
# 461805                                    Know Your Enemy   2017-06-12
# 453008                                                NaN   2017-06-11
# 305342                                                NaN   2017-06-02
# 455661               The Heart Wants What The Heart Wants   2017-06-01
# 459295                                                NaN   2017-05-30
# 419192                 Pioneer. Leader. Father. Champion.   2017-05-25
# 458310                                                NaN   2017-05-23
# 458298                           Who killed Sister Cathy?   2017-05-19
# 411007                                                NaN   2017-05-19
# 387426                                                NaN   2017-05-19
# 447818                                  Is there a limit?   2017-05-12
# 456348                                                NaN   2017-05-06
# 454787         Comedy can be found in the darkest places.   2017-05-06
# 464207                                                NaN   2017-05-01
# 450875                               The past is prologue   2017-04-28
# 450945                                                NaN   2017-04-23
# 452166                         Our country was his stage.   2017-04-22
# 355277                                                NaN   2017-04-21
# 283995                                         Obviously.   2017-04-19
# 411012                      The John Coltrane Documentary   2017-04-14
# 359784                       Triumph epitomizes adversity   2017-04-14
# ...                                                   ...          ...
# 264309                                                NaN   1929-12-20
# 42616                                                 NaN   1929-11-09
# 94716                                                 NaN   1929-10-01
# 105981                                                NaN   1929-08-18
# 288521                                                NaN   1929-02-28
# 28189                                                 NaN   1928-10-04
# 31411                                                 NaN   1928-09-16
# 42614                                                 NaN   1928-09-01
# 101482  With all the glamor and glitter of Coney Islan...   1928-06-20
# 28978                                                 NaN   1928-01-06
# 73969                                                 NaN   1927-10-31
# 27503                                                 NaN   1927-06-04
# 16661                                                 NaN   1927-01-17
# 961     Buster drives "The General" to trainload of la...   1926-12-31
# 128899        The screen's great lover in a dashing role!   1926-09-30
# 85638                                                 NaN   1926-08-09
# 73575                                                 NaN   1926-05-14
# 121379                                                NaN   1925-12-26
# 962                The World's Greatest Laughing Picture!   1925-06-25
# 1405                                                  NaN   1924-12-04
# 992             Every inch of footage holds such a laugh!   1924-04-21
# 701                         A Comedy with a Heart of Gold   1923-11-19
# 91208                                                 NaN   1923-04-22
# 23282                                                 NaN   1920-09-01
# 54242                                                 NaN   1918-08-01
# 47653                     "The Tramp" arrives in New York   1917-06-17
# 371758                 Agatha Christie's darkest thriller          NaN
# 410142                                                NaN          NaN
# 426224               Come See the Galaxy Like a Kid Again          NaN
# 425916                                                NaN          NaN
#
#                                          genres  \
# id
# 374471                            Romance|Drama
# 460135                                Animation
# 411741                             Drama|Comedy
# 374720        Action|Drama|History|Thriller|War
# 416477                     Comedy|Drama|Romance
# 461634                                   Comedy
# 382614                     Thriller|Drama|Crime
# 433471                                Animation
# 382127                                    Drama
# 461805                              Documentary
# 453008                              Documentary
# 305342                                   Comedy
# 455661          Family|Animation|Romance|Comedy
# 459295                                   Comedy
# 419192                              Documentary
# 458310                                   Comedy
# 458298                  Crime|Documentary|Drama
# 411007                              Documentary
# 387426  Adventure|Drama|Fantasy|Science Fiction
# 447818                              Documentary
# 456348                              Documentary
# 454787                                   Comedy
# 464207                              Documentary
# 450875                              Documentary
# 450945                              Documentary
# 452166                              Documentary
# 355277                              Documentary
# 283995  Action|Adventure|Comedy|Science Fiction
# 411012                              Documentary
# 359784                    Drama|History|Romance
# ...                                         ...
# 264309                             Comedy|Drama
# 42616                                   Western
# 94716                                     Drama
# 105981                            Romance|Drama
# 288521                           Romance|Comedy
# 28189                              Drama|Horror
# 31411                                    Comedy
# 42614                             Drama|Romance
# 101482                     Comedy|Drama|Romance
# 28978                              Comedy|Drama
# 73969                      Drama|Comedy|Romance
# 27503                      Drama|Horror|Romance
# 16661                              Comedy|Drama
# 961               Action|Adventure|Comedy|Drama
# 128899                     Action|Drama|Romance
# 85638                                     Drama
# 73575                                     Drama
# 121379                                   Comedy
# 962                      Adventure|Comedy|Drama
# 1405                              Drama|History
# 992                Fantasy|Drama|Comedy|Mystery
# 701                         Comedy|Drama|Family
# 91208                      Comedy|Drama|Romance
# 23282                                    Comedy
# 54242                              Comedy|Drama
# 47653                              Comedy|Drama
# 371758                      Crime|Mystery|Drama
# 410142                              Documentary
# 426224                              Documentary
# 425916         Animation|Horror|Science Fiction
#
#                      belongs_to_collection original_language  budget_musd  \
# id
# 374471                                 NaN                en          NaN
# 460135      DC Super Hero Girls Collection                en          NaN
# 411741                                 NaN                en          NaN
# 374720                                 NaN                en   100.000000
# 416477                                 NaN                en          NaN
# 461634                                 NaN                en          NaN
# 382614                                 NaN                en    10.000000
# 433471                                 NaN                en          NaN
# 382127                                 NaN                en     0.010000
# 461805                                 NaN                en          NaN
# 453008                                 NaN                en          NaN
# 305342                                 NaN                en          NaN
# 455661                                 NaN                en          NaN
# 459295                                 NaN                en          NaN
# 419192                                 NaN                en          NaN
# 458310                                 NaN                en          NaN
# 458298                                 NaN                en          NaN
# 411007                                 NaN                en          NaN
# 387426                                 NaN                en    50.000000
# 447818                                 NaN                en          NaN
# 456348                                 NaN                en          NaN
# 454787                                 NaN                en          NaN
# 464207                                 NaN                en          NaN
# 450875                                 NaN                en          NaN
# 450945                                 NaN                en          NaN
# 452166                                 NaN                en          NaN
# 355277                                 NaN                zh          NaN
# 283995  Guardians of the Galaxy Collection                en   200.000000
# 411012                                 NaN                en          NaN
# 359784                                 NaN                en          NaN
# ...                                    ...               ...          ...
# 264309                                 NaN                en          NaN
# 42616                                  NaN                en          NaN
# 94716                                  NaN                en          NaN
# 105981                                 NaN                en          NaN
# 288521                                 NaN                en          NaN
# 28189                                  NaN                fr          NaN
# 31411                                  NaN                en          NaN
# 42614                                  NaN                en          NaN
# 101482                                 NaN                en          NaN
# 28978                                  NaN                en     9.000000
# 73969                                  NaN                en     0.483103
# 27503        I Love a Mystery movie series                en     0.217000
# 16661                                  NaN                en          NaN
# 961                                    NaN                en     0.750000
# 128899                                 NaN                en          NaN
# 85638                                  NaN                en          NaN
# 73575                                  NaN                en     0.463455
# 121379                                 NaN                en     0.320000
# 962                                    NaN                en     0.923000
# 1405                                   NaN                en     0.546883
# 992                                    NaN                en          NaN
# 701                                    NaN                en          NaN
# 91208                                  NaN                en          NaN
# 23282                                  NaN                en          NaN
# 54242                                  NaN                en     0.250000
# 47653                                  NaN                en          NaN
# 371758                                 NaN                en          NaN
# 410142                                 NaN                en          NaN
# 426224                                 NaN                en          NaN
# 425916                                 NaN                en          NaN
#
#         revenue_musd                               production_companies  \
# id
# 374471           NaN                                                NaN
# 460135           NaN                             Warner Bros. Animation
# 411741           NaN  Star Thrower Entertainment|141 Entertainment|Neon
# 374720    519.876949  Canal+|Studio Canal|Warner Bros.|Syncopy|RatPa...
# 416477     52.620184  FilmNation Entertainment|Apatow Productions|Am...
# 461634           NaN                                            Netflix
# 382614      4.219536  Sidney Kimmel Entertainment|Double Nickel Ente...
# 433471           NaN                            Pixar Animation Studios
# 382127           NaN                 Bayerischer Rundfunk|Schiwago Film
# 461805           NaN  Ixtlan Productions|Showtime Documentary Films|...
# 453008           NaN                                                NaN
# 305342           NaN                 Honora Productions|Spring Pictures
# 455661           NaN                 Ringling College of Art and Design
# 459295           NaN                    NetFlix|Netflix|Netflix Studios
# 419192           NaN                           General Film Corporation
# 458310           NaN                                            Netflix
# 458298           NaN                       Netflix|Film 45|Tripod Media
# 411007           NaN                                   Kartemquin Films
# 387426           NaN  Plan B Entertainment|Lewis Pictures|Kate Stree...
# 447818           NaN                                Vladar Company, The
# 456348           NaN                                      9.14 Pictures
# 454787           NaN                                                NaN
# 464207           NaN                                                NaN
# 450875           NaN                                National Geographic
# 450945           NaN                                                NaN
# 452166           NaN                                                NaN
# 355277           NaN  Walt Disney Studios Motion Pictures|Disneynatu...
# 283995    863.416141                Walt Disney Pictures|Marvel Studios
# 411012      0.393970                    Meteor 17|Crew Neck Productions
# 359784           NaN                                                NaN
# ...              ...                                                ...
# 264309           NaN                          Metro-Goldwyn-Mayer (MGM)
# 42616            NaN                                 Paramount Pictures
# 94716            NaN  Svensk Filmindustri (SF)|British Instructional...
# 105981           NaN                               Fox Film Corporation
# 288521           NaN                            First National Pictures
# 28189            NaN                                 Films Jean Epstein
# 31411            NaN                          Metro-Goldwyn-Mayer (MGM)
# 42614            NaN                          Metro-Goldwyn-Mayer (MGM)
# 101482           NaN                                 Universal Pictures
# 28978            NaN                        Charles Chaplin Productions
# 73969       1.027757                              Mary Pickford Company
# 27503            NaN                          Metro-Goldwyn-Mayer (MGM)
# 16661            NaN                                                NaN
# 961              NaN  Buster Keaton Productions|Joseph M. Schenck Pr...
# 128899           NaN                          Metro-Goldwyn-Mayer (MGM)
# 85638            NaN                          Metro-Goldwyn-Mayer (MGM)
# 73575       0.966878                               Pickford Corporation
# 121379           NaN                                       Warner Bros.
# 962         2.500000                        Charles Chaplin Productions
# 1405             NaN                          Metro-Goldwyn-Mayer (MGM)
# 992              NaN                                     Metro Pictures
# 701              NaN                      Joseph M. Schenck Productions
# 91208            NaN                       Goldwyn Pictures Corporation
# 23282            NaN                      Joseph M. Schenck Productions
# 54242       8.000000                 Mabel Normand Feature Film Company
# 47653            NaN          Mutual Film Company|Lone Star Corporation
# 371758           NaN  British Broadcasting Corporation (BBC)|Mammoth...
# 410142           NaN                                                NaN
# 426224           NaN                                                NaN
# 425916           NaN                                                NaN
#
#                                      production_countries  ...  popularity  \
# id                                                         ...
# 374471    Poland|Portugal|France|United States of America  ...    2.152189
# 460135                           United States of America  ...    8.413734
# 411741                           United States of America  ...    3.647596
# 374720  Netherlands|France|United Kingdom|United State...  ...   30.938854
# 416477                           United States of America  ...   23.424794
# 461634                           United States of America  ...    0.593041
# 382614                           United States of America  ...   24.553725
# 433471                                                NaN  ...    1.770297
# 382127                                  Australia|Germany  ...    2.022670
# 461805                           United States of America  ...    0.642527
# 453008                                                NaN  ...    0.631435
# 305342                           United States of America  ...    1.807007
# 455661                           United States of America  ...   20.821780
# 459295                           United States of America  ...    0.828399
# 419192                                        New Zealand  ...    1.487037
# 458310                           United States of America  ...    1.531309
# 458298                           United States of America  ...    1.576170
# 411007                           United States of America  ...    0.759280
# 387426               South Korea|United States of America  ...   15.738471
# 447818                           United States of America  ...    2.004971
# 456348                           United States of America  ...    0.990632
# 454787                           United States of America  ...    1.135015
# 464207                                             Canada  ...    1.075249
# 450875                           United States of America  ...    0.855198
# 450945                                                NaN  ...    2.293791
# 452166                                                NaN  ...    0.206170
# 355277      United Kingdom|United States of America|China  ...    7.709977
# 283995                           United States of America  ...  185.330992
# 411012                           United States of America  ...    0.519968
# 359784                                             Canada  ...    6.404957
# ...                                                   ...  ...         ...
# 264309                           United States of America  ...    0.094685
# 42616                            United States of America  ...    0.037264
# 94716                               Sweden|United Kingdom  ...    0.465277
# 105981                           United States of America  ...    1.333157
# 288521                           United States of America  ...    0.374038
# 28189                                              France  ...    1.229788
# 31411                            United States of America  ...    4.824576
# 42614                            United States of America  ...    0.112326
# 101482                           United States of America  ...    1.671902
# 28978                            United States of America  ...    6.714813
# 73969                            United States of America  ...    0.205671
# 27503                            United States of America  ...    1.481620
# 16661                            United States of America  ...    1.132810
# 961                              United States of America  ...    8.002953
# 128899                           United States of America  ...    0.978542
# 85638                            United States of America  ...    0.284522
# 73575                            United States of America  ...    0.445526
# 121379                           United States of America  ...    0.497550
# 962                              United States of America  ...    6.202041
# 1405                             United States of America  ...    6.925081
# 992                              United States of America  ...    5.858328
# 701                              United States of America  ...    2.830289
# 91208                            United States of America  ...    0.211760
# 23282                            United States of America  ...    3.121673
# 54242                            United States of America  ...    0.211008
# 47653                            United States of America  ...    3.933922
# 371758                                     United Kingdom  ...    5.238281
# 410142                                                NaN  ...    0.001393
# 426224                           United States of America  ...    0.001182
# 425916                                     United Kingdom  ...    0.141367
#
#         runtime                                           overview  \
# id
# 374471     75.0  Jake and Mati are two outsiders in the norther...
# 460135      NaN  When Supergirl, Wonder Woman, Batgirl, Bumbleb...
# 411741     97.0  Ingrid becomes obsessed with a social network ...
# 374720    107.0  The miraculous evacuation of Allied soldiers f...
# 416477    120.0  Pakistan-born comedian Kumail Nanjiani and gra...
# 461634     66.0  Comedian Rory Scovel storms the stage in Atlan...
# 382614    105.0  Naomi Watts stars as Susan, a single mother of...
# 433471      6.0  A Pixar short about a lost-and-found box and t...
# 382127    130.0  Manifesto draws on the writings of Futurists, ...
# 461805    240.0  Academy Award-winning filmmaker, Oliver Stone ...
# 453008     99.0  A look at the current state of Syria amidst wa...
# 305342     87.0  A freelance illustrator in New York suffers a ...
# 455661      4.0  A closeted boy runs the risk of being outed by...
# 459295     71.0  In her first comedy special post-health scare,...
# 419192     94.0  The story of New Zealander, Bruce McLaren, who...
# 458310     72.0  Comic Hasan Minhaj of "The Daily Show" shares ...
# 458298    432.0  A seven-part docuseries about the unsolved mur...
# 411007     88.0  The incredible saga of the Chinese immigrant S...
# 387426    121.0  A young girl named Mija risks everything to pr...
# 447818    106.0  From the director of Generation Iron, comes th...
# 456348     93.0  Everyone thinks that Bob Kane created Batman, ...
# 454787     90.0  A comedy about depression, alcoholism, suicide...
# 464207     86.0  William Shatner sits down with scientists, inn...
# 450875    114.0  Twenty-five years after the verdict in the Rod...
# 450945     90.0  The life and career of an actor, artist, and i...
# 452166     75.0  Comprised entirely of archival footage taken d...
# 355277     76.0  Venturing into the wilds of China, "Born in Ch...
# 283995    137.0  The Guardians must fight to keep their newfoun...
# 411012     99.0  The film explores the global power and impact ...
# 359784    115.0  An unlikely romance in which the reclusive Eve...
# ...         ...                                                ...
# 264309     77.0  On shore leave, a young sailor meets and falls...
# 42616      91.0  A good-natured cowboy who is romancing the new...
# 94716      88.0  Flashback story of an escape from the lonely, ...
# 105981     90.0  Mary, a poor farm girl, meets Tim just as word...
# 288521     84.0  Colleen Moore as a flapper who unwittingly fal...
# 28189      63.0  Adapted from Edgar Allan Poe's Fall of the Hou...
# 31411      76.0  Buster is a tintype portrait photographer who ...
# 42614      84.0  Diana is outwardly the hit of the party but in...
# 101482     69.0  Two lonely people in the big city meet and enj...
# 28978      71.0  Charlie, a wandering tramp, becomes a circus h...
# 73969      80.0  Joe Merrill, son of the millionaire owner of a...
# 27503      63.0  Lon Chaney is carnival knife thrower Alonzo th...
# 16661      82.0  The most important family in Hickoryville is (...
# 961        79.0  During America’s Civil War Union spies steal e...
# 128899     90.0  Rafael Sabatini's story of the swashbuckling e...
# 85638     115.0  In Puritan Boston, seamstress Hester Prynne is...
# 73575      84.0  Evil Mr.Grimes keeps a rag-tag bunch orphans o...
# 121379    120.0  Mrs Erlynne, the mother of Lady Windermere - h...
# 962        95.0  A lone prospector ventures into Alaska looking...
# 1405      140.0  Greed is the classic 1924 silent film by Erich...
# 992        49.0  A film projectionist longs to be a detective, ...
# 701        73.0  A man returns to his Appalachian homestead. On...
# 91208      90.0  A young woman hits Hollywood, determined to be...
# 23282      25.0  The story involves two newlyweds, Keaton and S...
# 54242      93.0  Mickey, an orphan who has been brought up in a...
# 47653      20.0  Charlie is an immigrant who endures a challeng...
# 371758    168.0  Ten strangers, drawn away from their normal li...
# 410142      NaN  Lo Sound Desert is a documentary about the Cal...
# 426224     75.0  In 2009, students of all walks of life at the ...
# 425916     52.0  The adventures of Salad Fingers, an unspecifie...
#
#                   spoken_languages  \
# id
# 374471  English|Français|Português
# 460135    English|Polski|Português
# 411741                     English
# 374720    English|Français|Deutsch
# 416477                English|اردو
# 461634                     English
# 382614                     English
# 433471                     English
# 382127            English|Italiano
# 461805             English|Pусский
# 453008             العربية|English
# 305342                     English
# 455661                     English
# 459295                     English
# 419192                     English
# 458310         English|हिन्दी|اردو
# 458298                     English
# 411007                     English
# 387426     English|한국어/조선말|Español
# 447818                     English
# 456348                     English
# 454787                     English
# 464207                     English
# 450875                     English
# 450945                     English
# 452166                     English
# 355277         English|普通话|Español
# 283995                     English
# 411012                     English
# 359784            English|Français
# ...                            ...
# 264309                     English
# 42616                      English
# 94716                      English
# 105981                     English
# 288521                     English
# 28189                      English
# 31411                      English
# 42614                      English
# 101482                     English
# 28978                      English
# 73969                      English
# 27503                      English
# 16661                      English
# 961                        English
# 128899                     English
# 85638                      English
# 73575                      English
# 121379                     English
# 962                        English
# 1405                       English
# 992                        English
# 701                        English
# 91208                      English
# 23282                      English
# 54242                      English
# 47653             English|Italiano
# 371758     English|Français|Magyar
# 410142                     English
# 426224                     English
# 425916                     English
#
#                                               poster_path  \
# id
# 374471  <img src='http://image.tmdb.org/t/p/w185//2jsN...
# 460135  <img src='http://image.tmdb.org/t/p/w185//8wz6...
# 411741  <img src='http://image.tmdb.org/t/p/w185//3LEy...
# 374720  <img src='http://image.tmdb.org/t/p/w185//ebSn...
# 416477  <img src='http://image.tmdb.org/t/p/w185//qquE...
# 461634  <img src='http://image.tmdb.org/t/p/w185//z4pp...
# 382614  <img src='http://image.tmdb.org/t/p/w185//suLF...
# 433471  <img src='http://image.tmdb.org/t/p/w185//zAQm...
# 382127  <img src='http://image.tmdb.org/t/p/w185//eszm...
# 461805  <img src='http://image.tmdb.org/t/p/w185//irsz...
# 453008  <img src='http://image.tmdb.org/t/p/w185//m3TV...
# 305342  <img src='http://image.tmdb.org/t/p/w185//8cEQ...
# 455661  <img src='http://image.tmdb.org/t/p/w185//wJUJ...
# 459295  <img src='http://image.tmdb.org/t/p/w185//mLkM...
# 419192  <img src='http://image.tmdb.org/t/p/w185//yRWI...
# 458310  <img src='http://image.tmdb.org/t/p/w185//qnd3...
# 458298  <img src='http://image.tmdb.org/t/p/w185//ltmL...
# 411007  <img src='http://image.tmdb.org/t/p/w185//4u00...
# 387426  <img src='http://image.tmdb.org/t/p/w185//pHlR...
# 447818  <img src='http://image.tmdb.org/t/p/w185//cXZG...
# 456348  <img src='http://image.tmdb.org/t/p/w185//gc1o...
# 454787  <img src='http://image.tmdb.org/t/p/w185//66t6...
# 464207  <img src='http://image.tmdb.org/t/p/w185//7UfW...
# 450875  <img src='http://image.tmdb.org/t/p/w185//oT7O...
# 450945  <img src='http://image.tmdb.org/t/p/w185//96Sc...
# 452166  <img src='http://image.tmdb.org/t/p/w185//oNiJ...
# 355277  <img src='http://image.tmdb.org/t/p/w185//7oOH...
# 283995  <img src='http://image.tmdb.org/t/p/w185//y4MB...
# 411012  <img src='http://image.tmdb.org/t/p/w185//2yoy...
# 359784  <img src='http://image.tmdb.org/t/p/w185//wu9R...
# ...                                                   ...
# 264309  <img src='http://image.tmdb.org/t/p/w185//ubbX...
# 42616   <img src='http://image.tmdb.org/t/p/w185//dbPY...
# 94716   <img src='http://image.tmdb.org/t/p/w185//e2Am...
# 105981  <img src='http://image.tmdb.org/t/p/w185//2dan...
# 288521  <img src='http://image.tmdb.org/t/p/w185//mvHM...
# 28189   <img src='http://image.tmdb.org/t/p/w185//t8fq...
# 31411   <img src='http://image.tmdb.org/t/p/w185//prhM...
# 42614   <img src='http://image.tmdb.org/t/p/w185//sh3H...
# 101482  <img src='http://image.tmdb.org/t/p/w185//jo7w...
# 28978   <img src='http://image.tmdb.org/t/p/w185//hWw9...
# 73969   <img src='http://image.tmdb.org/t/p/w185//s7Cy...
# 27503   <img src='http://image.tmdb.org/t/p/w185//rmLq...
# 16661   <img src='http://image.tmdb.org/t/p/w185//wxh7...
# 961     <img src='http://image.tmdb.org/t/p/w185//wZ9R...
# 128899  <img src='http://image.tmdb.org/t/p/w185//9d2W...
# 85638   <img src='http://image.tmdb.org/t/p/w185//4c5u...
# 73575   <img src='http://image.tmdb.org/t/p/w185//3ZPf...
# 121379  <img src='http://image.tmdb.org/t/p/w185//fpDP...
# 962     <img src='http://image.tmdb.org/t/p/w185//eQRF...
# 1405    <img src='http://image.tmdb.org/t/p/w185//eur2...
# 992     <img src='http://image.tmdb.org/t/p/w185//1G9r...
# 701     <img src='http://image.tmdb.org/t/p/w185//lQrE...
# 91208   <img src='http://image.tmdb.org/t/p/w185//hsx4...
# 23282   <img src='http://image.tmdb.org/t/p/w185//gIP9...
# 54242   <img src='http://image.tmdb.org/t/p/w185//9yzM...
# 47653   <img src='http://image.tmdb.org/t/p/w185//uCRk...
# 371758  <img src='http://image.tmdb.org/t/p/w185//j80t...
# 410142  <img src='http://image.tmdb.org/t/p/w185//pecG...
# 426224  <img src='http://image.tmdb.org/t/p/w185//exhs...
# 425916  <img src='http://image.tmdb.org/t/p/w185//xQEW...
#
#                                                      cast cast_size crew_size  \
# id
# 374471  Lucie Lucas|Anton Yelchin|Paulo Calatré|Franço...         5        17
# 460135  Grey Griffin|Tara Strong|Anais Fairweather|Tea...        17         6
# 411741  Aubrey Plaza|Elizabeth Olsen|O'Shea Jackson Jr...        21        19
# 374720  Fionn Whitehead|Tom Glynn-Carney|Jack Lowden|H...        66       214
# 416477  Kumail Nanjiani|Zoe Kazan|Holly Hunter|Ray Rom...        44       129
# 461634                                        Rory Scovel         1         2
# 382614  Naomi Watts|Jaeden Lieberher|Jacob Tremblay|Sa...        27        27
# 433471                                                NaN         0         1
# 382127  Cate Blanchett|Erika Bauer|Ruby Bustamante|Car...        12         2
# 461805                        Vladimir Putin|Oliver Stone         2         2
# 453008                                   Sebastian Junger         1         2
# 305342  Demetri Martin|Gillian Jacobs|Christine Woods|...        10         4
# 455661                                                NaN         0         7
# 459295                                    Sarah Silverman         1        11
# 419192  Dwayne Cameron|Mario Andretti|Alastair Caldwel...         5        18
# 458310                                                NaN         0         2
# 458298                                                NaN         0        12
# 411007  Neil Barofsky|Ti-Hua Chang|Jiayang Fan|Roman F...        15         6
# 387426  Tilda Swinton|Paul Dano|Ahn Seo-hyun |Byun Hee...        46        32
# 447818              Calum Von Moger|Kai Greene|Rich Piana         3         1
# 456348  Michael Uslan|Roy Thomas|Marc Tyler Nobleman|T...        12        11
# 454787                                      Chris Gethard         1         3
# 464207  William Shatner|Neil deGrasse Tyson|Chris Hadf...         9         1
# 450875  Rodney King|Tom Brokaw|George H. W. Bush|Bill ...         7         8
# 450945  Heath Ledger|Kate Ledger|Kim Ledger|Olivia Led...        14         8
# 452166  Ronald Reagan|Nancy Reagan|Barbara Walters|Wal...         7         8
# 355277                            John Krasinski|Zhou Xun         2         8
# 283995  Chris Pratt|Zoe Saldana|Dave Bautista|Vin Dies...        63       131
# 411012  Denzel Washington|Common|Bill Clinton|Carlos S...         9         8
# 359784  Sally Hawkins|Ethan Hawke|Gabrielle Rose|Billy...        16        27
# ...                                                   ...       ...       ...
# 264309  William Haines|Anita Page|Karl Dane|J.C. Nugen...        25        11
# 42616   Gary Cooper|Walter Huston|Richard Arlen|Mary B...         9        17
# 94716   Norah Baring|Uno Henning|Hans Adalbert Schlett...         5         4
# 105981  Janet Gaynor|Charles Farrell|Guinn Williams|Pa...         9        11
# 288521  Colleen Moore|Neil Hamilton|Bodil Rosing|John ...        19         5
# 28189   Jean Debucourt|Marguerite Gance|Charles Lamy|F...         9         9
# 31411   Buster Keaton|Marceline Day|Harold Goodwin|Sid...        14        14
# 42614   Joan Crawford|Johnny Mack Brown|Nils Asther|Do...        11         8
# 101482  Barbara Kent|Glenn Tryon|Fay Holderness|Gusztá...         6         8
# 28978   Charlie Chaplin|Al Ernest Garcia|Merna Kennedy...         9         2
# 73969   Mary Pickford|Charles 'Buddy' Rogers|Sunshine ...        23        10
# 27503   Lon Chaney|Joan Crawford|Norman Kerry|Nick De ...         6         6
# 16661   Harold Lloyd|Jobyna Ralston|Walter James|Leo W...         9         8
# 961     Buster Keaton|Marion Mack|Glen Cavender|Jim Fa...        22        25
# 128899  John Gilbert|Eleanor Boardman|Roy D'Arcy|Lione...         6        11
# 85638   Lillian Gish|Lars Hanson|Henry B. Walthall|Kar...         6         3
# 73575   Mary Pickford|Roy Stewart|Mary Louise Miller|G...        15         5
# 121379  Ronald Colman|May McAvoy|Bert Lytell|Irene Ric...         6        10
# 962     Charlie Chaplin|Georgia Hale|Mack Swain|Tom Mu...        40        20
# 1405    Zasu Pitts|Gibson Gowland|Jean Hersholt|Dale F...        24        26
# 992     Buster Keaton|Kathryn McGuire|Joe Keaton|Erwin...        12        13
# 701     Buster Keaton|Joe Roberts|Natalie Talmadge|Ral...        13        13
# 91208   Eleanor Boardman|Frank Mayo|Richard Dix|Mae Bu...        81         7
# 23282               Buster Keaton|Sybil Seely|Joe Roberts         3         5
# 54242   Mabel Normand|George Nichols|Wheeler Oakman|Mi...         8         5
# 47653   Charlie Chaplin|Edna Purviance|Eric Campbell|A...        15        13
# 371758                                                NaN         0         0
# 410142              Joshua Homme|Brant Bjork|Nick Oliveri         3         2
# 426224                                                NaN         0         2
# 425916                                        David Firth         1         1
#
#                   director  profit_musd
# id
# 374471        Gabe Klinger          NaN
# 460135         Todd Grimes          NaN
# 411741         Matt Spicer          NaN
# 374720   Christopher Nolan   419.876949
# 416477   Michael Showalter          NaN
# 461634         Scott Moran          NaN
# 382614     Colin Trevorrow    -5.780464
# 433471        Dave Mullins          NaN
# 382127    Julian Rosefeldt          NaN
# 461805        Oliver Stone          NaN
# 453008    Sebastian Junger          NaN
# 305342      Demetri Martin          NaN
# 455661          Beth David          NaN
# 459295          Liam Lynch          NaN
# 419192     Roger Donaldson          NaN
# 458310  Christopher Storer          NaN
# 458298          Ryan White          NaN
# 411007         Steve James          NaN
# 387426        Bong Joon-ho          NaN
# 447818          Vlad Yudin          NaN
# 456348          Don Argott          NaN
# 454787     Kimberly Senior          NaN
# 464207      Craig Thompson          NaN
# 450875         T.J. Martin          NaN
# 450945        Derik Murray          NaN
# 452166   Sierra Pettengill          NaN
# 355277            Lu Chuan          NaN
# 283995          James Gunn   663.416141
# 411012     John Scheinfeld          NaN
# 359784       Aisling Walsh          NaN
# ...                    ...          ...
# 264309      Clarence Brown          NaN
# 42616       Victor Fleming          NaN
# 94716      Anthony Asquith          NaN
# 105981       Frank Borzage          NaN
# 288521   William A. Seiter          NaN
# 28189         Jean Epstein          NaN
# 31411        Buster Keaton          NaN
# 42614       Harry Beaumont          NaN
# 101482           Pál Fejős          NaN
# 28978      Charlie Chaplin          NaN
# 73969           Sam Taylor     0.544654
# 27503         Tod Browning          NaN
# 16661            Ted Wilde          NaN
# 961          Buster Keaton          NaN
# 128899          King Vidor          NaN
# 85638      Victor Sjöström          NaN
# 73575     William Beaudine     0.503423
# 121379      Ernst Lubitsch          NaN
# 962        Charlie Chaplin     1.577000
# 1405    Erich von Stroheim          NaN
# 992          Buster Keaton          NaN
# 701          Buster Keaton          NaN
# 91208        Rupert Hughes          NaN
# 23282        Buster Keaton          NaN
# 54242     F. Richard Jones     7.750000
# 47653      Charlie Chaplin          NaN
# 371758                 NaN          NaN
# 410142       Jörg Steineck          NaN
# 426224          Tim Larson          NaN
# 425916                 NaN          NaN
#
# [2163 rows x 22 columns]

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
movies1 = movies.copy()
movies1['franchise'] = np.where(movies1['belongs_to_collection'].isnull(), 'Stand_alone', 'Franchise')
movies1.head()
movies1.groupby(by ='franchise')['revenue_musd'].mean()
# Out:
# franchise
# Franchise      165.708193
# Stand_alone     44.742814
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__
